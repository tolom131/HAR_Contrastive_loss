# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Lambda
from tensorflow.keras.utils import Sequence
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow_addons as tfa

import numpy as np
import math
import matplotlib.pyplot as plt
import time
import os

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score

from data.pamap2.pamap2 import create_pamap2
from other_models.attention import har_model
from other_models.attention.attentive_pooling import AttentionWithContext


from data.pamap2.pamap2 import create_pamap2

# %%
import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
def window_warp(x, window_ratio=0.1, scales=[0.5, 2.]):
    # https://halshs.archives-ouvertes.fr/halshs-01357973/document
    warp_scales = np.random.choice(scales, x.shape[0])
    warp_size = np.ceil(window_ratio*x.shape[1]).astype(int)
    window_steps = np.arange(warp_size)
        
    window_starts = np.random.randint(low=1, high=x.shape[1]-warp_size-1, size=(x.shape[0])).astype(int)
    window_ends = (window_starts + warp_size).astype(int)
            
    ret = np.zeros_like(x)
    for i, pat in enumerate(x):
        for dim in range(x.shape[2]):
            start_seg = pat[:window_starts[i],dim]
            window_seg = np.interp(np.linspace(0, warp_size-1, num=int(warp_size*warp_scales[i])), window_steps, pat[window_starts[i]:window_ends[i],dim])
            end_seg = pat[window_ends[i]:,dim]
            warped = np.concatenate((start_seg, window_seg, end_seg))                
            ret[i,:,dim] = np.interp(np.arange(x.shape[1]), np.linspace(0, x.shape[1]-1., num=warped.size), warped).T
    return ret

class Dataloader(Sequence):

    def __init__(self, x_set, y_set, batch_size, shuffle=False, finetuning=False):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.finetuning = finetuning
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.x) / self.batch_size)

    def __getitem__(self, idx):
        indices = self.indices[idx*self.batch_size:(idx+1)*self.batch_size]

        batch_x = [self.x[i] for i in indices]
        batch_y = [self.y[i] for i in indices]
        batch_x, batch_y = np.array(batch_x), np.array(batch_y)

        if not self.finetuning:
            batch_x = window_warp(batch_x)

        return batch_x, batch_y

    # epoch이 끝날때마다 실행
    def on_epoch_end(self):
        self.indices = np.arange(len(self.x))
        if self.shuffle == True:
            np.random.shuffle(self.indices)

# %%
secs = time.time()
tm = time.localtime(secs)

time_string = time.strftime('%Y%m%d%I%M%S', tm)
time_int = int(time_string) % (2**32 - 1)
time_string = str(time_int)
print('random_state : ' , time_int)
# Out:
# random_state :  3039869

# %%
# def CNN_Set(input_shape, kernel_size, name="Set"):
    
#     inputs = tf.keras.layers.Input(input_shape)
#     conv1 = tf.keras.layers.Conv1D(64, kernel_size=kernel_size, activation="relu")
#     conv2 = tf.keras.layers.Conv1D(32, kernel_size=kernel_size, activation="relu")
#     dropout = tf.keras.layers.Dropout(0.5)
#     maxpooling = tf.keras.layers.MaxPool1D(pool_size=2)
#     flatten = tf.keras.layers.Flatten()
    
#     x = tf.keras.layers.TimeDistributed(conv1)(inputs)
#     x = tf.keras.layers.TimeDistributed(conv2)(x)
#     x = tf.keras.layers.TimeDistributed(dropout)(x)
#     x = tf.keras.layers.TimeDistributed(maxpooling)(x)
#     x = tf.keras.layers.TimeDistributed(flatten)(x)
    
#     model = tf.keras.models.Model(inputs, x, name=name)
#     return model

def Encoder(input_shape, name="encoder"):
    
    attention = har_model.create_model(100, 18, _dff=256, d_model=128, nh=4, dropout_rate=0.2, use_pe=True)

    inputs = tf.keras.layers.Input(input_shape)
    output = attention(inputs)
    
    model = tf.keras.models.Model(inputs, output, name=name)
    return model

def Balancing_Contrastive(input_shape, contrastive_outputs, n_outputs):
    inputs = tf.keras.layers.Input(input_shape)
    encoded = Encoder(input_shape)(inputs)
    classified = tf.keras.layers.Dense(n_outputs * 4, activation='relu')(encoded) #, kernel_regularizer=tf.keras.regularizers.l2(0.005)
    classified = tf.keras.layers.Dropout(0.2)(classified)

    classified = tf.keras.layers.Dense(n_outputs, activation='softmax', name="classified")(classified) #, kernel_regularizer=tf.keras.regularizers.l2(0.005)
    ### contrastive
    contrastive = tf.keras.layers.LayerNormalization()(encoded)
    contrastive = tf.keras.layers.Dense(contrastive_outputs, activation="relu", name="contrastive")(contrastive)
    
    model = tf.keras.models.Model(inputs=inputs, outputs=[classified, contrastive], name="Balancing")     
    return model

# %%
batch = 64
epcohs = 100
learning_rate = 0.005

# %%
class SampleContrastiveLoss(tf.keras.losses.Loss):
    def __init__(self, batch, lam=0.0001, beta=0.5, margin=1.2, name=None):
        super(SampleContrastiveLoss, self).__init__(name=name)
        self.batch = batch
        self.lam = lam
        self.beta = beta
        self.margin = margin
        
        self.tril = tf.cast(tf.linalg.band_part(tf.ones(shape=(batch, batch)), -1, 0) == 1, tf.bool)
        # self.tril = tf.cast(tf.linalg.band_part(tf.ones(shape=(batch, batch)), -1, 0) == 1, tf.int32)
        self.crossentropy = tf.keras.losses.SparseCategoricalCrossentropy()
        
    def __call__(self, labels, feature_vectors, sample_weight=None):
        print(labels.shape, feature_vectors.shape)
        feature_vectors_normalized = tf.math.l2_normalize(feature_vectors, axis=1)
        r1 = tf.matmul(feature_vectors_normalized, tf.transpose(feature_vectors_normalized))
        r2 = tf.abs(tf.subtract(tf.expand_dims(labels, axis=1), tf.expand_dims(labels, axis=0)))
        r2 = tf.experimental.numpy.squeeze(r2, axis=-1)
        
        mask1 = tf.where(self.tril, tf.ones(shape=(self.batch, self.batch)), tf.cast(r2, tf.float32)) == 0
        mask2 = tf.where(self.tril, tf.zeros(shape=(self.batch, self.batch)), tf.cast(r2, tf.float32)) > 0
        
        sample_loss = self.lam * tf.math.reduce_sum(r1[mask1]) + self.beta * tf.nn.relu(tf.math.reduce_sum(self.margin - r1[mask2]))
        sample_loss = sample_loss / batch
        return sample_loss

class SupervisedContrastiveLoss(tf.keras.losses.Loss):
    def __init__(self, temperature=0.1, name=None):
        super(SupervisedContrastiveLoss, self).__init__(name=name)
        self.temperature = temperature

    def __call__(self, labels, feature_vectors, sample_weight=None):
        # Normalize feature vectors
        feature_vectors_normalized = tf.math.l2_normalize(feature_vectors, axis=1)
        # Compute logits
        logits = tf.divide(
            tf.matmul(
                feature_vectors_normalized, tf.transpose(feature_vectors_normalized)
            ),
            self.temperature,
        )
        return tfa.losses.npairs_loss(tf.squeeze(labels), logits)

# %%
def create_dataset(name, data_type="frequency_100"):
    print("creating dataset")
    if name == "pamap2":
        x_train, y_train = create_pamap2(data=data_type)

        # 80%, 10%, 10% respectively in train, val, test dataset
        x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
        #x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=time_int, stratify=y_train)
        x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42, stratify=y_test)
        #x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=time_int, stratify=y_test)
        print("x_train.shape : ", x_train.shape, "y_train.shape: ", y_train.shape)
        print("x_val.shape   : ", x_val.shape,    "y_val.shape: ", y_val.shape)
        print("x_test.shape  : ", x_test.shape,   "y_test.shape: ", y_test.shape)

        return x_train, y_train, x_val, y_val, x_test, y_test

# %%
dataset_name = "pamap2"  
x_train, y_train, x_val, y_val, x_test, y_test = create_dataset(name=dataset_name, data_type="nooverlap")

print("contrastive_y_train shape : ", y_train.shape)
print("contrastive_y_val shape : ", y_val.shape)
print("contrastive_y_test shape : ", y_test.shape)
# Out:
# creating dataset
# /home/dongi/har/HAR_Contrastive_loss/nooverlap
# x_train.shape :  (15502, 100, 18) y_train.shape:  (15502,)
# x_val.shape   :  (1938, 100, 18) y_val.shape:  (1938,)
# x_test.shape  :  (1938, 100, 18) y_test.shape:  (1938,)
# contrastive_y_train shape :  (15502,)
# contrastive_y_val shape :  (1938,)
# contrastive_y_test shape :  (1938,)

# %%
train_loader = Dataloader(x_train, y_train, 64, shuffle=True, finetuning=True)
valid_loader = Dataloader(x_val, y_val, 64, finetuning=True)
test_loader = Dataloader(x_test, y_test, 2, finetuning=True)

# %%
filepath = "result/attention_frequency_" + dataset_name + "_" + time_string + ".h5"
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_classified_loss', factor=0.5, patience=5, min_lr=0.0001)
checkpoint = ModelCheckpoint(filepath, verbose = 0, monitor="val_classified_loss", mode="min", save_best_only=True, save_weights_only = True)
#checkpoint = ModelCheckpoint(filepath, verbose = 1, monitor="val_classified_accuracy", mode="max", save_best_only=True, save_weights_only = True)
#earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_classified_loss', min_delta=0, patience=30, mode='min', restore_best_weights=True)
print("[Prtraninig Encoder with Supervised Contrastive Loss]")
model = Balancing_Contrastive(x_train.shape[1:], 64, len(np.unique(y_train)))
model.summary()

model.compile(loss=["sparse_categorical_crossentropy", SupervisedContrastiveLoss()], loss_weights=[0.1, 0.9], optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), metrics=["accuracy"])
# history = model.fit(frequency_100_x_train, [frequency_100_y_train, contrastive_y_train], validation_data=(frequency_100_x_val, [frequency_100_y_val, contrastive_y_val]), batch_size=32, epochs=50, verbose=1, callbacks=[reduce_lr, checkpoint])
history = model.fit(train_loader, validation_data=valid_loader, batch_size=batch, epochs=epcohs, verbose=1, callbacks=[reduce_lr, checkpoint])
print("[Finished Prtraining]")
# Out:
# [Prtraninig Encoder with Supervised Contrastive Loss]
# 2022-07-09 18:47:32.170672: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-09 18:47:32.856931: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20657 MB memory:  -> device: 0, name: NVIDIA A10, pci bus id: 0000:52:00.0, compute capability: 8.6
# Model: "Balancing"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 18)]    0           []
#
#  encoder (Functional)           (None, 128)          285221      ['input_1[0][0]']
#
#  dense_12 (Dense)               (None, 48)           6192        ['encoder[0][0]']
#
#  dropout_5 (Dropout)            (None, 48)           0           ['dense_12[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 128)         256         ['encoder[0][0]']
#  rmalization)
#
#  classified (Dense)             (None, 12)           588         ['dropout_5[0][0]']
#
#  contrastive (Dense)            (None, 64)           8256        ['layer_normalization_5[0][0]']
#
# ==================================================================================================
# Total params: 300,513
# Trainable params: 300,513
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 2022-07-09 18:47:39.135794: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
# 2022-07-09 18:47:41.660790: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 243/243 [==============================] - 16s 36ms/step - loss: 3.0784 - classified_loss: 1.4690 - contrastive_loss: 3.2572 - classified_accuracy: 0.4799 - contrastive_accuracy: 0.0060 - val_loss: 2.8209 - val_classified_loss: 1.0739 - val_contrastive_loss: 3.0150 - val_classified_accuracy: 0.6115 - val_contrastive_accuracy: 0.0015 - lr: 0.0050
# Epoch 2/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.8575 - classified_loss: 1.1631 - contrastive_loss: 3.0458 - classified_accuracy: 0.6206 - contrastive_accuracy: 0.0013 - val_loss: 2.9136 - val_classified_loss: 1.1801 - val_contrastive_loss: 3.1062 - val_classified_accuracy: 0.6207 - val_contrastive_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 3/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.7614 - classified_loss: 1.0354 - contrastive_loss: 2.9532 - classified_accuracy: 0.6978 - contrastive_accuracy: 5.8057e-04 - val_loss: 2.6864 - val_classified_loss: 0.9474 - val_contrastive_loss: 2.8797 - val_classified_accuracy: 0.7188 - val_contrastive_accuracy: 0.0015 - lr: 0.0050
# Epoch 4/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.7422 - classified_loss: 1.0003 - contrastive_loss: 2.9357 - classified_accuracy: 0.7113 - contrastive_accuracy: 0.0013 - val_loss: 2.6606 - val_classified_loss: 0.8954 - val_contrastive_loss: 2.8568 - val_classified_accuracy: 0.7601 - val_contrastive_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 5/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.7089 - classified_loss: 0.9594 - contrastive_loss: 2.9033 - classified_accuracy: 0.7227 - contrastive_accuracy: 0.0039 - val_loss: 2.6147 - val_classified_loss: 0.8450 - val_contrastive_loss: 2.8113 - val_classified_accuracy: 0.7699 - val_contrastive_accuracy: 0.0031 - lr: 0.0050
# Epoch 6/100
# 243/243 [==============================] - 6s 26ms/step - loss: 2.7338 - classified_loss: 0.9604 - contrastive_loss: 2.9308 - classified_accuracy: 0.7271 - contrastive_accuracy: 0.0042 - val_loss: 2.6038 - val_classified_loss: 0.8213 - val_contrastive_loss: 2.8019 - val_classified_accuracy: 0.7523 - val_contrastive_accuracy: 0.0031 - lr: 0.0050
# Epoch 7/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.9031 - classified_loss: 1.1520 - contrastive_loss: 3.0977 - classified_accuracy: 0.6472 - contrastive_accuracy: 0.0054 - val_loss: 3.1235 - val_classified_loss: 1.3856 - val_contrastive_loss: 3.3166 - val_classified_accuracy: 0.5325 - val_contrastive_accuracy: 0.0103 - lr: 0.0050
# Epoch 8/100
# 243/243 [==============================] - 7s 29ms/step - loss: 3.0648 - classified_loss: 1.3326 - contrastive_loss: 3.2572 - classified_accuracy: 0.5857 - contrastive_accuracy: 0.0107 - val_loss: 2.8445 - val_classified_loss: 1.1138 - val_contrastive_loss: 3.0368 - val_classified_accuracy: 0.6765 - val_contrastive_accuracy: 0.0031 - lr: 0.0050
# Epoch 9/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.9476 - classified_loss: 1.1984 - contrastive_loss: 3.1420 - classified_accuracy: 0.6424 - contrastive_accuracy: 0.0031 - val_loss: 2.8395 - val_classified_loss: 1.0200 - val_contrastive_loss: 3.0417 - val_classified_accuracy: 0.6997 - val_contrastive_accuracy: 0.0046 - lr: 0.0050
# Epoch 10/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.8530 - classified_loss: 1.0913 - contrastive_loss: 3.0488 - classified_accuracy: 0.6784 - contrastive_accuracy: 0.0023 - val_loss: 2.7517 - val_classified_loss: 1.0017 - val_contrastive_loss: 2.9462 - val_classified_accuracy: 0.7126 - val_contrastive_accuracy: 0.0021 - lr: 0.0050
# Epoch 11/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.8826 - classified_loss: 1.1051 - contrastive_loss: 3.0801 - classified_accuracy: 0.6673 - contrastive_accuracy: 0.0033 - val_loss: 2.7904 - val_classified_loss: 1.0393 - val_contrastive_loss: 2.9850 - val_classified_accuracy: 0.6920 - val_contrastive_accuracy: 0.0062 - lr: 0.0050
# Epoch 12/100
# 243/243 [==============================] - 8s 33ms/step - loss: 2.8036 - classified_loss: 0.9937 - contrastive_loss: 3.0047 - classified_accuracy: 0.7042 - contrastive_accuracy: 0.0039 - val_loss: 2.6563 - val_classified_loss: 0.7965 - val_contrastive_loss: 2.8629 - val_classified_accuracy: 0.7637 - val_contrastive_accuracy: 0.0041 - lr: 0.0025
# Epoch 13/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.7849 - classified_loss: 0.9764 - contrastive_loss: 2.9858 - classified_accuracy: 0.7099 - contrastive_accuracy: 0.0029 - val_loss: 2.7605 - val_classified_loss: 0.9486 - val_contrastive_loss: 2.9618 - val_classified_accuracy: 0.7085 - val_contrastive_accuracy: 0.0155 - lr: 0.0025
# Epoch 14/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.8262 - classified_loss: 1.0215 - contrastive_loss: 3.0267 - classified_accuracy: 0.6896 - contrastive_accuracy: 0.0025 - val_loss: 2.8059 - val_classified_loss: 0.9924 - val_contrastive_loss: 3.0074 - val_classified_accuracy: 0.6987 - val_contrastive_accuracy: 0.0119 - lr: 0.0025
# Epoch 15/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.8685 - classified_loss: 1.0612 - contrastive_loss: 3.0693 - classified_accuracy: 0.6765 - contrastive_accuracy: 0.0041 - val_loss: 2.7924 - val_classified_loss: 0.9633 - val_contrastive_loss: 2.9956 - val_classified_accuracy: 0.6997 - val_contrastive_accuracy: 0.0021 - lr: 0.0025
# Epoch 16/100
# 243/243 [==============================] - 7s 31ms/step - loss: 2.8239 - classified_loss: 1.0164 - contrastive_loss: 3.0247 - classified_accuracy: 0.6944 - contrastive_accuracy: 0.0028 - val_loss: 2.7291 - val_classified_loss: 0.8987 - val_contrastive_loss: 2.9324 - val_classified_accuracy: 0.7327 - val_contrastive_accuracy: 0.0010 - lr: 0.0025
# Epoch 17/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.7531 - classified_loss: 0.9449 - contrastive_loss: 2.9540 - classified_accuracy: 0.7273 - contrastive_accuracy: 0.0029 - val_loss: 2.6732 - val_classified_loss: 0.8356 - val_contrastive_loss: 2.8774 - val_classified_accuracy: 0.7601 - val_contrastive_accuracy: 0.0052 - lr: 0.0025
# Epoch 18/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.7126 - classified_loss: 0.8906 - contrastive_loss: 2.9150 - classified_accuracy: 0.7437 - contrastive_accuracy: 0.0023 - val_loss: 2.6377 - val_classified_loss: 0.7906 - val_contrastive_loss: 2.8429 - val_classified_accuracy: 0.7807 - val_contrastive_accuracy: 0.0041 - lr: 0.0012
# Epoch 19/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.6793 - classified_loss: 0.8584 - contrastive_loss: 2.8816 - classified_accuracy: 0.7525 - contrastive_accuracy: 0.0020 - val_loss: 2.6191 - val_classified_loss: 0.7926 - val_contrastive_loss: 2.8220 - val_classified_accuracy: 0.7755 - val_contrastive_accuracy: 0.0031 - lr: 0.0012
# Epoch 20/100
# 243/243 [==============================] - 9s 35ms/step - loss: 2.6747 - classified_loss: 0.8455 - contrastive_loss: 2.8779 - classified_accuracy: 0.7535 - contrastive_accuracy: 0.0037 - val_loss: 2.6201 - val_classified_loss: 0.7887 - val_contrastive_loss: 2.8236 - val_classified_accuracy: 0.7807 - val_contrastive_accuracy: 0.0052 - lr: 0.0012
# Epoch 21/100
# 243/243 [==============================] - 6s 26ms/step - loss: 2.6879 - classified_loss: 0.8672 - contrastive_loss: 2.8902 - classified_accuracy: 0.7491 - contrastive_accuracy: 0.0039 - val_loss: 2.6208 - val_classified_loss: 0.7902 - val_contrastive_loss: 2.8242 - val_classified_accuracy: 0.7750 - val_contrastive_accuracy: 0.0041 - lr: 0.0012
# Epoch 22/100
# 243/243 [==============================] - 5s 22ms/step - loss: 2.6566 - classified_loss: 0.8388 - contrastive_loss: 2.8586 - classified_accuracy: 0.7544 - contrastive_accuracy: 0.0029 - val_loss: 2.5937 - val_classified_loss: 0.7678 - val_contrastive_loss: 2.7966 - val_classified_accuracy: 0.7833 - val_contrastive_accuracy: 0.0026 - lr: 0.0012
# Epoch 23/100
# 243/243 [==============================] - 6s 26ms/step - loss: 2.6553 - classified_loss: 0.8322 - contrastive_loss: 2.8578 - classified_accuracy: 0.7613 - contrastive_accuracy: 0.0033 - val_loss: 2.6026 - val_classified_loss: 0.7717 - val_contrastive_loss: 2.8060 - val_classified_accuracy: 0.7869 - val_contrastive_accuracy: 0.0021 - lr: 0.0012
# Epoch 24/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.6583 - classified_loss: 0.8346 - contrastive_loss: 2.8609 - classified_accuracy: 0.7577 - contrastive_accuracy: 0.0036 - val_loss: 2.6039 - val_classified_loss: 0.8060 - val_contrastive_loss: 2.8037 - val_classified_accuracy: 0.7797 - val_contrastive_accuracy: 0.0021 - lr: 0.0012
# Epoch 25/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.6286 - classified_loss: 0.8043 - contrastive_loss: 2.8313 - classified_accuracy: 0.7670 - contrastive_accuracy: 0.0034 - val_loss: 2.5673 - val_classified_loss: 0.7399 - val_contrastive_loss: 2.7703 - val_classified_accuracy: 0.7967 - val_contrastive_accuracy: 0.0036 - lr: 0.0012
# Epoch 26/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.6341 - classified_loss: 0.8129 - contrastive_loss: 2.8364 - classified_accuracy: 0.7671 - contrastive_accuracy: 0.0036 - val_loss: 2.5964 - val_classified_loss: 0.7656 - val_contrastive_loss: 2.7999 - val_classified_accuracy: 0.7905 - val_contrastive_accuracy: 0.0036 - lr: 0.0012
# Epoch 27/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.6299 - classified_loss: 0.8171 - contrastive_loss: 2.8313 - classified_accuracy: 0.7656 - contrastive_accuracy: 0.0035 - val_loss: 2.5845 - val_classified_loss: 0.7752 - val_contrastive_loss: 2.7855 - val_classified_accuracy: 0.7745 - val_contrastive_accuracy: 0.0026 - lr: 0.0012
# Epoch 28/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.6319 - classified_loss: 0.8097 - contrastive_loss: 2.8344 - classified_accuracy: 0.7660 - contrastive_accuracy: 0.0035 - val_loss: 2.5700 - val_classified_loss: 0.7547 - val_contrastive_loss: 2.7717 - val_classified_accuracy: 0.7874 - val_contrastive_accuracy: 0.0021 - lr: 0.0012
# Epoch 29/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.6167 - classified_loss: 0.7910 - contrastive_loss: 2.8195 - classified_accuracy: 0.7716 - contrastive_accuracy: 0.0036 - val_loss: 2.5638 - val_classified_loss: 0.7482 - val_contrastive_loss: 2.7655 - val_classified_accuracy: 0.7941 - val_contrastive_accuracy: 0.0031 - lr: 0.0012
# Epoch 30/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.6176 - classified_loss: 0.7920 - contrastive_loss: 2.8205 - classified_accuracy: 0.7729 - contrastive_accuracy: 0.0043 - val_loss: 2.5463 - val_classified_loss: 0.7184 - val_contrastive_loss: 2.7494 - val_classified_accuracy: 0.7957 - val_contrastive_accuracy: 0.0057 - lr: 0.0012
# Epoch 31/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.6009 - classified_loss: 0.7773 - contrastive_loss: 2.8035 - classified_accuracy: 0.7775 - contrastive_accuracy: 0.0038 - val_loss: 2.5525 - val_classified_loss: 0.7359 - val_contrastive_loss: 2.7543 - val_classified_accuracy: 0.7993 - val_contrastive_accuracy: 0.0015 - lr: 0.0012
# Epoch 32/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.5997 - classified_loss: 0.7796 - contrastive_loss: 2.8019 - classified_accuracy: 0.7763 - contrastive_accuracy: 0.0034 - val_loss: 2.5857 - val_classified_loss: 0.7918 - val_contrastive_loss: 2.7850 - val_classified_accuracy: 0.7755 - val_contrastive_accuracy: 0.0057 - lr: 0.0012
# Epoch 33/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.5895 - classified_loss: 0.7646 - contrastive_loss: 2.7923 - classified_accuracy: 0.7800 - contrastive_accuracy: 0.0034 - val_loss: 2.5417 - val_classified_loss: 0.7301 - val_contrastive_loss: 2.7430 - val_classified_accuracy: 0.8024 - val_contrastive_accuracy: 0.0015 - lr: 0.0012
# Epoch 34/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.5808 - classified_loss: 0.7634 - contrastive_loss: 2.7828 - classified_accuracy: 0.7798 - contrastive_accuracy: 0.0035 - val_loss: 2.5605 - val_classified_loss: 0.7432 - val_contrastive_loss: 2.7624 - val_classified_accuracy: 0.7982 - val_contrastive_accuracy: 5.1600e-04 - lr: 0.0012
# Epoch 35/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.5905 - classified_loss: 0.7694 - contrastive_loss: 2.7928 - classified_accuracy: 0.7794 - contrastive_accuracy: 0.0042 - val_loss: 2.5457 - val_classified_loss: 0.7119 - val_contrastive_loss: 2.7495 - val_classified_accuracy: 0.7998 - val_contrastive_accuracy: 0.0021 - lr: 0.0012
# Epoch 36/100
# 243/243 [==============================] - 8s 30ms/step - loss: 2.5900 - classified_loss: 0.7725 - contrastive_loss: 2.7920 - classified_accuracy: 0.7796 - contrastive_accuracy: 0.0041 - val_loss: 2.5523 - val_classified_loss: 0.7257 - val_contrastive_loss: 2.7553 - val_classified_accuracy: 0.8008 - val_contrastive_accuracy: 0.0010 - lr: 0.0012
# Epoch 37/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.5824 - classified_loss: 0.7535 - contrastive_loss: 2.7856 - classified_accuracy: 0.7824 - contrastive_accuracy: 0.0041 - val_loss: 2.5268 - val_classified_loss: 0.6955 - val_contrastive_loss: 2.7303 - val_classified_accuracy: 0.8075 - val_contrastive_accuracy: 0.0026 - lr: 0.0012
# Epoch 38/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.6098 - classified_loss: 0.7931 - contrastive_loss: 2.8117 - classified_accuracy: 0.7732 - contrastive_accuracy: 0.0037 - val_loss: 2.6069 - val_classified_loss: 0.7959 - val_contrastive_loss: 2.8081 - val_classified_accuracy: 0.7755 - val_contrastive_accuracy: 0.0052 - lr: 0.0012
# Epoch 39/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.5946 - classified_loss: 0.7695 - contrastive_loss: 2.7974 - classified_accuracy: 0.7773 - contrastive_accuracy: 0.0048 - val_loss: 2.5575 - val_classified_loss: 0.7120 - val_contrastive_loss: 2.7626 - val_classified_accuracy: 0.7859 - val_contrastive_accuracy: 0.0057 - lr: 0.0012
# Epoch 40/100
# 243/243 [==============================] - 7s 31ms/step - loss: 2.5842 - classified_loss: 0.7648 - contrastive_loss: 2.7863 - classified_accuracy: 0.7794 - contrastive_accuracy: 0.0037 - val_loss: 2.5560 - val_classified_loss: 0.7263 - val_contrastive_loss: 2.7593 - val_classified_accuracy: 0.7926 - val_contrastive_accuracy: 0.0067 - lr: 0.0012
# Epoch 41/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.5746 - classified_loss: 0.7505 - contrastive_loss: 2.7773 - classified_accuracy: 0.7837 - contrastive_accuracy: 0.0039 - val_loss: 2.5464 - val_classified_loss: 0.7115 - val_contrastive_loss: 2.7503 - val_classified_accuracy: 0.7946 - val_contrastive_accuracy: 0.0046 - lr: 0.0012
# Epoch 42/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.5739 - classified_loss: 0.7497 - contrastive_loss: 2.7766 - classified_accuracy: 0.7858 - contrastive_accuracy: 0.0045 - val_loss: 2.5506 - val_classified_loss: 0.7268 - val_contrastive_loss: 2.7532 - val_classified_accuracy: 0.7951 - val_contrastive_accuracy: 0.0031 - lr: 0.0012
# Epoch 43/100
# 243/243 [==============================] - 7s 31ms/step - loss: 2.5653 - classified_loss: 0.7352 - contrastive_loss: 2.7686 - classified_accuracy: 0.7856 - contrastive_accuracy: 0.0043 - val_loss: 2.5314 - val_classified_loss: 0.6862 - val_contrastive_loss: 2.7364 - val_classified_accuracy: 0.8091 - val_contrastive_accuracy: 0.0026 - lr: 6.2500e-04
# Epoch 44/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.5572 - classified_loss: 0.7314 - contrastive_loss: 2.7601 - classified_accuracy: 0.7929 - contrastive_accuracy: 0.0045 - val_loss: 2.5447 - val_classified_loss: 0.7073 - val_contrastive_loss: 2.7489 - val_classified_accuracy: 0.8039 - val_contrastive_accuracy: 0.0046 - lr: 6.2500e-04
# Epoch 45/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.5536 - classified_loss: 0.7251 - contrastive_loss: 2.7568 - classified_accuracy: 0.7949 - contrastive_accuracy: 0.0042 - val_loss: 2.5288 - val_classified_loss: 0.6942 - val_contrastive_loss: 2.7327 - val_classified_accuracy: 0.8034 - val_contrastive_accuracy: 0.0036 - lr: 6.2500e-04
# Epoch 46/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.5486 - classified_loss: 0.7184 - contrastive_loss: 2.7519 - classified_accuracy: 0.7934 - contrastive_accuracy: 0.0044 - val_loss: 2.5260 - val_classified_loss: 0.6855 - val_contrastive_loss: 2.7305 - val_classified_accuracy: 0.8086 - val_contrastive_accuracy: 0.0036 - lr: 6.2500e-04
# Epoch 47/100
# 243/243 [==============================] - 7s 31ms/step - loss: 2.5616 - classified_loss: 0.7303 - contrastive_loss: 2.7650 - classified_accuracy: 0.7912 - contrastive_accuracy: 0.0036 - val_loss: 2.4959 - val_classified_loss: 0.6603 - val_contrastive_loss: 2.6998 - val_classified_accuracy: 0.8184 - val_contrastive_accuracy: 0.0010 - lr: 6.2500e-04
# Epoch 48/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.5228 - classified_loss: 0.7025 - contrastive_loss: 2.7251 - classified_accuracy: 0.7992 - contrastive_accuracy: 0.0034 - val_loss: 2.5037 - val_classified_loss: 0.6685 - val_contrastive_loss: 2.7076 - val_classified_accuracy: 0.8148 - val_contrastive_accuracy: 0.0021 - lr: 6.2500e-04
# Epoch 49/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.5266 - classified_loss: 0.6985 - contrastive_loss: 2.7298 - classified_accuracy: 0.7969 - contrastive_accuracy: 0.0028 - val_loss: 2.4863 - val_classified_loss: 0.6417 - val_contrastive_loss: 2.6912 - val_classified_accuracy: 0.8184 - val_contrastive_accuracy: 0.0015 - lr: 6.2500e-04
# Epoch 50/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.5138 - classified_loss: 0.6981 - contrastive_loss: 2.7156 - classified_accuracy: 0.8007 - contrastive_accuracy: 0.0029 - val_loss: 2.4939 - val_classified_loss: 0.6538 - val_contrastive_loss: 2.6983 - val_classified_accuracy: 0.8132 - val_contrastive_accuracy: 0.0026 - lr: 6.2500e-04
# Epoch 51/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.5086 - classified_loss: 0.6847 - contrastive_loss: 2.7112 - classified_accuracy: 0.8034 - contrastive_accuracy: 0.0028 - val_loss: 2.4864 - val_classified_loss: 0.6580 - val_contrastive_loss: 2.6896 - val_classified_accuracy: 0.8142 - val_contrastive_accuracy: 0.0015 - lr: 6.2500e-04
# Epoch 52/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.5143 - classified_loss: 0.6915 - contrastive_loss: 2.7168 - classified_accuracy: 0.8026 - contrastive_accuracy: 0.0034 - val_loss: 2.4731 - val_classified_loss: 0.6464 - val_contrastive_loss: 2.6761 - val_classified_accuracy: 0.8204 - val_contrastive_accuracy: 0.0010 - lr: 6.2500e-04
# Epoch 53/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.5061 - classified_loss: 0.6866 - contrastive_loss: 2.7083 - classified_accuracy: 0.8037 - contrastive_accuracy: 0.0034 - val_loss: 2.4732 - val_classified_loss: 0.6369 - val_contrastive_loss: 2.6772 - val_classified_accuracy: 0.8153 - val_contrastive_accuracy: 0.0031 - lr: 6.2500e-04
# Epoch 54/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.5112 - classified_loss: 0.6872 - contrastive_loss: 2.7138 - classified_accuracy: 0.8014 - contrastive_accuracy: 0.0034 - val_loss: 2.4674 - val_classified_loss: 0.6347 - val_contrastive_loss: 2.6711 - val_classified_accuracy: 0.8220 - val_contrastive_accuracy: 0.0031 - lr: 6.2500e-04
# Epoch 55/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.5031 - classified_loss: 0.6834 - contrastive_loss: 2.7053 - classified_accuracy: 0.8062 - contrastive_accuracy: 0.0039 - val_loss: 2.4663 - val_classified_loss: 0.6324 - val_contrastive_loss: 2.6701 - val_classified_accuracy: 0.8225 - val_contrastive_accuracy: 5.1600e-04 - lr: 6.2500e-04
# Epoch 56/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.5001 - classified_loss: 0.6739 - contrastive_loss: 2.7030 - classified_accuracy: 0.8077 - contrastive_accuracy: 0.0032 - val_loss: 2.4495 - val_classified_loss: 0.6105 - val_contrastive_loss: 2.6538 - val_classified_accuracy: 0.8292 - val_contrastive_accuracy: 0.0015 - lr: 6.2500e-04
# Epoch 57/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4955 - classified_loss: 0.6762 - contrastive_loss: 2.6976 - classified_accuracy: 0.8081 - contrastive_accuracy: 0.0039 - val_loss: 2.4530 - val_classified_loss: 0.6247 - val_contrastive_loss: 2.6561 - val_classified_accuracy: 0.8168 - val_contrastive_accuracy: 0.0010 - lr: 6.2500e-04
# Epoch 58/100
# 243/243 [==============================] - 8s 35ms/step - loss: 2.5043 - classified_loss: 0.6805 - contrastive_loss: 2.7070 - classified_accuracy: 0.8043 - contrastive_accuracy: 0.0034 - val_loss: 2.4476 - val_classified_loss: 0.6092 - val_contrastive_loss: 2.6518 - val_classified_accuracy: 0.8251 - val_contrastive_accuracy: 0.0026 - lr: 6.2500e-04
# Epoch 59/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.5040 - classified_loss: 0.6809 - contrastive_loss: 2.7066 - classified_accuracy: 0.8064 - contrastive_accuracy: 0.0038 - val_loss: 2.4791 - val_classified_loss: 0.6503 - val_contrastive_loss: 2.6823 - val_classified_accuracy: 0.8179 - val_contrastive_accuracy: 0.0026 - lr: 6.2500e-04
# Epoch 60/100
# 243/243 [==============================] - 7s 31ms/step - loss: 2.4998 - classified_loss: 0.6772 - contrastive_loss: 2.7023 - classified_accuracy: 0.8049 - contrastive_accuracy: 0.0041 - val_loss: 2.4599 - val_classified_loss: 0.6227 - val_contrastive_loss: 2.6640 - val_classified_accuracy: 0.8215 - val_contrastive_accuracy: 0.0021 - lr: 6.2500e-04
# Epoch 61/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.5052 - classified_loss: 0.6828 - contrastive_loss: 2.7077 - classified_accuracy: 0.8047 - contrastive_accuracy: 0.0038 - val_loss: 2.4783 - val_classified_loss: 0.6442 - val_contrastive_loss: 2.6821 - val_classified_accuracy: 0.8215 - val_contrastive_accuracy: 0.0036 - lr: 6.2500e-04
# Epoch 62/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.5055 - classified_loss: 0.6844 - contrastive_loss: 2.7078 - classified_accuracy: 0.8073 - contrastive_accuracy: 0.0045 - val_loss: 2.5028 - val_classified_loss: 0.6633 - val_contrastive_loss: 2.7072 - val_classified_accuracy: 0.8117 - val_contrastive_accuracy: 0.0021 - lr: 6.2500e-04
# Epoch 63/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.5223 - classified_loss: 0.6893 - contrastive_loss: 2.7260 - classified_accuracy: 0.8027 - contrastive_accuracy: 0.0050 - val_loss: 2.4526 - val_classified_loss: 0.6157 - val_contrastive_loss: 2.6567 - val_classified_accuracy: 0.8235 - val_contrastive_accuracy: 0.0046 - lr: 6.2500e-04
# Epoch 64/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4892 - classified_loss: 0.6603 - contrastive_loss: 2.6924 - classified_accuracy: 0.8114 - contrastive_accuracy: 0.0048 - val_loss: 2.4282 - val_classified_loss: 0.5993 - val_contrastive_loss: 2.6315 - val_classified_accuracy: 0.8328 - val_contrastive_accuracy: 0.0046 - lr: 3.1250e-04
# Epoch 65/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4681 - classified_loss: 0.6459 - contrastive_loss: 2.6706 - classified_accuracy: 0.8165 - contrastive_accuracy: 0.0044 - val_loss: 2.4405 - val_classified_loss: 0.6040 - val_contrastive_loss: 2.6446 - val_classified_accuracy: 0.8287 - val_contrastive_accuracy: 0.0041 - lr: 3.1250e-04
# Epoch 66/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4754 - classified_loss: 0.6501 - contrastive_loss: 2.6782 - classified_accuracy: 0.8151 - contrastive_accuracy: 0.0043 - val_loss: 2.4412 - val_classified_loss: 0.5976 - val_contrastive_loss: 2.6460 - val_classified_accuracy: 0.8308 - val_contrastive_accuracy: 0.0046 - lr: 3.1250e-04
# Epoch 67/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4672 - classified_loss: 0.6477 - contrastive_loss: 2.6694 - classified_accuracy: 0.8167 - contrastive_accuracy: 0.0048 - val_loss: 2.4345 - val_classified_loss: 0.5884 - val_contrastive_loss: 2.6396 - val_classified_accuracy: 0.8302 - val_contrastive_accuracy: 0.0041 - lr: 3.1250e-04
# Epoch 68/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4713 - classified_loss: 0.6458 - contrastive_loss: 2.6741 - classified_accuracy: 0.8190 - contrastive_accuracy: 0.0053 - val_loss: 2.4433 - val_classified_loss: 0.6040 - val_contrastive_loss: 2.6476 - val_classified_accuracy: 0.8287 - val_contrastive_accuracy: 0.0046 - lr: 3.1250e-04
# Epoch 69/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4650 - classified_loss: 0.6349 - contrastive_loss: 2.6684 - classified_accuracy: 0.8184 - contrastive_accuracy: 0.0050 - val_loss: 2.4396 - val_classified_loss: 0.6097 - val_contrastive_loss: 2.6429 - val_classified_accuracy: 0.8277 - val_contrastive_accuracy: 0.0036 - lr: 3.1250e-04
# Epoch 70/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4746 - classified_loss: 0.6431 - contrastive_loss: 2.6781 - classified_accuracy: 0.8176 - contrastive_accuracy: 0.0050 - val_loss: 2.4340 - val_classified_loss: 0.6058 - val_contrastive_loss: 2.6371 - val_classified_accuracy: 0.8292 - val_contrastive_accuracy: 0.0036 - lr: 3.1250e-04
# Epoch 71/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.4642 - classified_loss: 0.6404 - contrastive_loss: 2.6668 - classified_accuracy: 0.8163 - contrastive_accuracy: 0.0047 - val_loss: 2.4298 - val_classified_loss: 0.5952 - val_contrastive_loss: 2.6336 - val_classified_accuracy: 0.8313 - val_contrastive_accuracy: 0.0036 - lr: 3.1250e-04
# Epoch 72/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4548 - classified_loss: 0.6314 - contrastive_loss: 2.6574 - classified_accuracy: 0.8216 - contrastive_accuracy: 0.0046 - val_loss: 2.4332 - val_classified_loss: 0.5970 - val_contrastive_loss: 2.6372 - val_classified_accuracy: 0.8318 - val_contrastive_accuracy: 0.0041 - lr: 3.1250e-04
# Epoch 73/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.4546 - classified_loss: 0.6320 - contrastive_loss: 2.6572 - classified_accuracy: 0.8189 - contrastive_accuracy: 0.0051 - val_loss: 2.4289 - val_classified_loss: 0.5918 - val_contrastive_loss: 2.6330 - val_classified_accuracy: 0.8292 - val_contrastive_accuracy: 0.0046 - lr: 1.5625e-04
# Epoch 74/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4578 - classified_loss: 0.6322 - contrastive_loss: 2.6607 - classified_accuracy: 0.8203 - contrastive_accuracy: 0.0046 - val_loss: 2.4225 - val_classified_loss: 0.5827 - val_contrastive_loss: 2.6269 - val_classified_accuracy: 0.8338 - val_contrastive_accuracy: 0.0041 - lr: 1.5625e-04
# Epoch 75/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4571 - classified_loss: 0.6276 - contrastive_loss: 2.6603 - classified_accuracy: 0.8213 - contrastive_accuracy: 0.0050 - val_loss: 2.4267 - val_classified_loss: 0.5921 - val_contrastive_loss: 2.6305 - val_classified_accuracy: 0.8328 - val_contrastive_accuracy: 0.0036 - lr: 1.5625e-04
# Epoch 76/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4552 - classified_loss: 0.6268 - contrastive_loss: 2.6584 - classified_accuracy: 0.8220 - contrastive_accuracy: 0.0045 - val_loss: 2.4192 - val_classified_loss: 0.5880 - val_contrastive_loss: 2.6226 - val_classified_accuracy: 0.8318 - val_contrastive_accuracy: 0.0036 - lr: 1.5625e-04
# Epoch 77/100
# 243/243 [==============================] - 8s 33ms/step - loss: 2.4537 - classified_loss: 0.6285 - contrastive_loss: 2.6565 - classified_accuracy: 0.8203 - contrastive_accuracy: 0.0041 - val_loss: 2.4167 - val_classified_loss: 0.5779 - val_contrastive_loss: 2.6210 - val_classified_accuracy: 0.8313 - val_contrastive_accuracy: 0.0036 - lr: 1.5625e-04
# Epoch 78/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4543 - classified_loss: 0.6279 - contrastive_loss: 2.6572 - classified_accuracy: 0.8234 - contrastive_accuracy: 0.0043 - val_loss: 2.4157 - val_classified_loss: 0.5819 - val_contrastive_loss: 2.6195 - val_classified_accuracy: 0.8349 - val_contrastive_accuracy: 0.0041 - lr: 1.5625e-04
# Epoch 79/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4567 - classified_loss: 0.6234 - contrastive_loss: 2.6604 - classified_accuracy: 0.8201 - contrastive_accuracy: 0.0043 - val_loss: 2.4186 - val_classified_loss: 0.5760 - val_contrastive_loss: 2.6233 - val_classified_accuracy: 0.8338 - val_contrastive_accuracy: 0.0041 - lr: 1.5625e-04
# Epoch 80/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4579 - classified_loss: 0.6267 - contrastive_loss: 2.6613 - classified_accuracy: 0.8218 - contrastive_accuracy: 0.0046 - val_loss: 2.4211 - val_classified_loss: 0.5799 - val_contrastive_loss: 2.6257 - val_classified_accuracy: 0.8354 - val_contrastive_accuracy: 0.0031 - lr: 1.5625e-04
# Epoch 81/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4495 - classified_loss: 0.6210 - contrastive_loss: 2.6527 - classified_accuracy: 0.8222 - contrastive_accuracy: 0.0049 - val_loss: 2.4163 - val_classified_loss: 0.5801 - val_contrastive_loss: 2.6203 - val_classified_accuracy: 0.8369 - val_contrastive_accuracy: 0.0046 - lr: 1.5625e-04
# Epoch 82/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4439 - classified_loss: 0.6175 - contrastive_loss: 2.6469 - classified_accuracy: 0.8225 - contrastive_accuracy: 0.0052 - val_loss: 2.4232 - val_classified_loss: 0.5807 - val_contrastive_loss: 2.6280 - val_classified_accuracy: 0.8333 - val_contrastive_accuracy: 0.0046 - lr: 1.5625e-04
# Epoch 83/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.4476 - classified_loss: 0.6210 - contrastive_loss: 2.6505 - classified_accuracy: 0.8213 - contrastive_accuracy: 0.0041 - val_loss: 2.4231 - val_classified_loss: 0.5840 - val_contrastive_loss: 2.6275 - val_classified_accuracy: 0.8323 - val_contrastive_accuracy: 0.0046 - lr: 1.5625e-04
# Epoch 84/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4404 - classified_loss: 0.6161 - contrastive_loss: 2.6431 - classified_accuracy: 0.8236 - contrastive_accuracy: 0.0045 - val_loss: 2.4237 - val_classified_loss: 0.5834 - val_contrastive_loss: 2.6282 - val_classified_accuracy: 0.8338 - val_contrastive_accuracy: 0.0046 - lr: 1.5625e-04
# Epoch 85/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4499 - classified_loss: 0.6136 - contrastive_loss: 2.6539 - classified_accuracy: 0.8249 - contrastive_accuracy: 0.0049 - val_loss: 2.4216 - val_classified_loss: 0.5797 - val_contrastive_loss: 2.6262 - val_classified_accuracy: 0.8364 - val_contrastive_accuracy: 0.0052 - lr: 1.0000e-04
# Epoch 86/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4444 - classified_loss: 0.6164 - contrastive_loss: 2.6475 - classified_accuracy: 0.8245 - contrastive_accuracy: 0.0045 - val_loss: 2.4197 - val_classified_loss: 0.5812 - val_contrastive_loss: 2.6239 - val_classified_accuracy: 0.8364 - val_contrastive_accuracy: 0.0041 - lr: 1.0000e-04
# Epoch 87/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4533 - classified_loss: 0.6203 - contrastive_loss: 2.6570 - classified_accuracy: 0.8228 - contrastive_accuracy: 0.0039 - val_loss: 2.4173 - val_classified_loss: 0.5778 - val_contrastive_loss: 2.6217 - val_classified_accuracy: 0.8406 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 88/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.4439 - classified_loss: 0.6157 - contrastive_loss: 2.6470 - classified_accuracy: 0.8265 - contrastive_accuracy: 0.0043 - val_loss: 2.4225 - val_classified_loss: 0.5766 - val_contrastive_loss: 2.6276 - val_classified_accuracy: 0.8395 - val_contrastive_accuracy: 0.0041 - lr: 1.0000e-04
# Epoch 89/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4415 - classified_loss: 0.6137 - contrastive_loss: 2.6446 - classified_accuracy: 0.8264 - contrastive_accuracy: 0.0042 - val_loss: 2.4167 - val_classified_loss: 0.5755 - val_contrastive_loss: 2.6212 - val_classified_accuracy: 0.8369 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 90/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4407 - classified_loss: 0.6147 - contrastive_loss: 2.6436 - classified_accuracy: 0.8245 - contrastive_accuracy: 0.0044 - val_loss: 2.4136 - val_classified_loss: 0.5785 - val_contrastive_loss: 2.6174 - val_classified_accuracy: 0.8338 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 91/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4460 - classified_loss: 0.6177 - contrastive_loss: 2.6492 - classified_accuracy: 0.8236 - contrastive_accuracy: 0.0050 - val_loss: 2.4135 - val_classified_loss: 0.5785 - val_contrastive_loss: 2.6174 - val_classified_accuracy: 0.8385 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 92/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4412 - classified_loss: 0.6136 - contrastive_loss: 2.6443 - classified_accuracy: 0.8277 - contrastive_accuracy: 0.0043 - val_loss: 2.4197 - val_classified_loss: 0.5831 - val_contrastive_loss: 2.6238 - val_classified_accuracy: 0.8359 - val_contrastive_accuracy: 0.0052 - lr: 1.0000e-04
# Epoch 93/100
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4392 - classified_loss: 0.6079 - contrastive_loss: 2.6426 - classified_accuracy: 0.8261 - contrastive_accuracy: 0.0044 - val_loss: 2.4126 - val_classified_loss: 0.5733 - val_contrastive_loss: 2.6169 - val_classified_accuracy: 0.8416 - val_contrastive_accuracy: 0.0041 - lr: 1.0000e-04
# Epoch 94/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.4411 - classified_loss: 0.6139 - contrastive_loss: 2.6441 - classified_accuracy: 0.8225 - contrastive_accuracy: 0.0045 - val_loss: 2.4183 - val_classified_loss: 0.5802 - val_contrastive_loss: 2.6225 - val_classified_accuracy: 0.8349 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 95/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4441 - classified_loss: 0.6209 - contrastive_loss: 2.6467 - classified_accuracy: 0.8244 - contrastive_accuracy: 0.0044 - val_loss: 2.4163 - val_classified_loss: 0.5769 - val_contrastive_loss: 2.6207 - val_classified_accuracy: 0.8369 - val_contrastive_accuracy: 0.0041 - lr: 1.0000e-04
# Epoch 96/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.4397 - classified_loss: 0.6162 - contrastive_loss: 2.6423 - classified_accuracy: 0.8252 - contrastive_accuracy: 0.0043 - val_loss: 2.4145 - val_classified_loss: 0.5730 - val_contrastive_loss: 2.6191 - val_classified_accuracy: 0.8354 - val_contrastive_accuracy: 0.0041 - lr: 1.0000e-04
# Epoch 97/100
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4351 - classified_loss: 0.6097 - contrastive_loss: 2.6379 - classified_accuracy: 0.8269 - contrastive_accuracy: 0.0048 - val_loss: 2.4181 - val_classified_loss: 0.5756 - val_contrastive_loss: 2.6228 - val_classified_accuracy: 0.8390 - val_contrastive_accuracy: 0.0052 - lr: 1.0000e-04
# Epoch 98/100
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4404 - classified_loss: 0.6133 - contrastive_loss: 2.6434 - classified_accuracy: 0.8254 - contrastive_accuracy: 0.0041 - val_loss: 2.4183 - val_classified_loss: 0.5785 - val_contrastive_loss: 2.6227 - val_classified_accuracy: 0.8369 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 99/100
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4311 - classified_loss: 0.6134 - contrastive_loss: 2.6331 - classified_accuracy: 0.8265 - contrastive_accuracy: 0.0042 - val_loss: 2.4127 - val_classified_loss: 0.5725 - val_contrastive_loss: 2.6171 - val_classified_accuracy: 0.8411 - val_contrastive_accuracy: 0.0057 - lr: 1.0000e-04
# Epoch 100/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.4356 - classified_loss: 0.6165 - contrastive_loss: 2.6378 - classified_accuracy: 0.8260 - contrastive_accuracy: 0.0054 - val_loss: 2.4144 - val_classified_loss: 0.5751 - val_contrastive_loss: 2.6187 - val_classified_accuracy: 0.8375 - val_contrastive_accuracy: 0.0041 - lr: 1.0000e-04
# [Finished Prtraining]

# %%
history2 = model.fit(train_loader, validation_data=valid_loader, batch_size=batch, epochs=epcohs+100, verbose=1, callbacks=[reduce_lr, checkpoint])
# Out:
# Epoch 1/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4333 - classified_loss: 0.6174 - contrastive_loss: 2.6350 - classified_accuracy: 0.8258 - contrastive_accuracy: 0.0045 - val_loss: 2.4091 - val_classified_loss: 0.5693 - val_contrastive_loss: 2.6135 - val_classified_accuracy: 0.8411 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 2/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4361 - classified_loss: 0.6098 - contrastive_loss: 2.6390 - classified_accuracy: 0.8265 - contrastive_accuracy: 0.0038 - val_loss: 2.4112 - val_classified_loss: 0.5702 - val_contrastive_loss: 2.6158 - val_classified_accuracy: 0.8400 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 3/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4408 - classified_loss: 0.6082 - contrastive_loss: 2.6445 - classified_accuracy: 0.8278 - contrastive_accuracy: 0.0046 - val_loss: 2.4105 - val_classified_loss: 0.5682 - val_contrastive_loss: 2.6152 - val_classified_accuracy: 0.8406 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 4/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4378 - classified_loss: 0.6080 - contrastive_loss: 2.6411 - classified_accuracy: 0.8284 - contrastive_accuracy: 0.0048 - val_loss: 2.4096 - val_classified_loss: 0.5723 - val_contrastive_loss: 2.6138 - val_classified_accuracy: 0.8411 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 5/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4297 - classified_loss: 0.6069 - contrastive_loss: 2.6322 - classified_accuracy: 0.8298 - contrastive_accuracy: 0.0040 - val_loss: 2.4059 - val_classified_loss: 0.5687 - val_contrastive_loss: 2.6101 - val_classified_accuracy: 0.8416 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 6/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4345 - classified_loss: 0.6083 - contrastive_loss: 2.6374 - classified_accuracy: 0.8285 - contrastive_accuracy: 0.0045 - val_loss: 2.4101 - val_classified_loss: 0.5728 - val_contrastive_loss: 2.6143 - val_classified_accuracy: 0.8364 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 7/200
# 243/243 [==============================] - 6s 26ms/step - loss: 2.4309 - classified_loss: 0.6089 - contrastive_loss: 2.6334 - classified_accuracy: 0.8273 - contrastive_accuracy: 0.0043 - val_loss: 2.4049 - val_classified_loss: 0.5649 - val_contrastive_loss: 2.6094 - val_classified_accuracy: 0.8426 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 8/200
# 243/243 [==============================] - 6s 23ms/step - loss: 2.4257 - classified_loss: 0.6071 - contrastive_loss: 2.6278 - classified_accuracy: 0.8298 - contrastive_accuracy: 0.0040 - val_loss: 2.4108 - val_classified_loss: 0.5725 - val_contrastive_loss: 2.6150 - val_classified_accuracy: 0.8380 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 9/200
# 243/243 [==============================] - 6s 23ms/step - loss: 2.4345 - classified_loss: 0.6098 - contrastive_loss: 2.6372 - classified_accuracy: 0.8265 - contrastive_accuracy: 0.0049 - val_loss: 2.4096 - val_classified_loss: 0.5677 - val_contrastive_loss: 2.6143 - val_classified_accuracy: 0.8385 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 10/200
# 243/243 [==============================] - 6s 26ms/step - loss: 2.4410 - classified_loss: 0.6102 - contrastive_loss: 2.6445 - classified_accuracy: 0.8259 - contrastive_accuracy: 0.0048 - val_loss: 2.4074 - val_classified_loss: 0.5655 - val_contrastive_loss: 2.6121 - val_classified_accuracy: 0.8437 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 11/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4344 - classified_loss: 0.6067 - contrastive_loss: 2.6375 - classified_accuracy: 0.8271 - contrastive_accuracy: 0.0045 - val_loss: 2.4079 - val_classified_loss: 0.5677 - val_contrastive_loss: 2.6124 - val_classified_accuracy: 0.8416 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 12/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4339 - classified_loss: 0.6092 - contrastive_loss: 2.6367 - classified_accuracy: 0.8255 - contrastive_accuracy: 0.0043 - val_loss: 2.4084 - val_classified_loss: 0.5655 - val_contrastive_loss: 2.6132 - val_classified_accuracy: 0.8406 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 13/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4333 - classified_loss: 0.6083 - contrastive_loss: 2.6360 - classified_accuracy: 0.8265 - contrastive_accuracy: 0.0041 - val_loss: 2.4093 - val_classified_loss: 0.5656 - val_contrastive_loss: 2.6142 - val_classified_accuracy: 0.8359 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 14/200
# 243/243 [==============================] - 6s 26ms/step - loss: 2.4332 - classified_loss: 0.6050 - contrastive_loss: 2.6363 - classified_accuracy: 0.8269 - contrastive_accuracy: 0.0041 - val_loss: 2.4033 - val_classified_loss: 0.5581 - val_contrastive_loss: 2.6083 - val_classified_accuracy: 0.8390 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 15/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4223 - classified_loss: 0.6032 - contrastive_loss: 2.6244 - classified_accuracy: 0.8287 - contrastive_accuracy: 0.0051 - val_loss: 2.4097 - val_classified_loss: 0.5656 - val_contrastive_loss: 2.6146 - val_classified_accuracy: 0.8426 - val_contrastive_accuracy: 0.0041 - lr: 1.0000e-04
# Epoch 16/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4308 - classified_loss: 0.6048 - contrastive_loss: 2.6337 - classified_accuracy: 0.8291 - contrastive_accuracy: 0.0042 - val_loss: 2.4115 - val_classified_loss: 0.5696 - val_contrastive_loss: 2.6161 - val_classified_accuracy: 0.8369 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 17/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4217 - classified_loss: 0.5989 - contrastive_loss: 2.6243 - classified_accuracy: 0.8287 - contrastive_accuracy: 0.0039 - val_loss: 2.4110 - val_classified_loss: 0.5654 - val_contrastive_loss: 2.6161 - val_classified_accuracy: 0.8375 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 18/200
# 243/243 [==============================] - 7s 31ms/step - loss: 2.4313 - classified_loss: 0.6034 - contrastive_loss: 2.6344 - classified_accuracy: 0.8299 - contrastive_accuracy: 0.0045 - val_loss: 2.4078 - val_classified_loss: 0.5624 - val_contrastive_loss: 2.6129 - val_classified_accuracy: 0.8437 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 19/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4251 - classified_loss: 0.6007 - contrastive_loss: 2.6278 - classified_accuracy: 0.8313 - contrastive_accuracy: 0.0044 - val_loss: 2.4135 - val_classified_loss: 0.5751 - val_contrastive_loss: 2.6178 - val_classified_accuracy: 0.8406 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 20/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4249 - classified_loss: 0.6086 - contrastive_loss: 2.6267 - classified_accuracy: 0.8281 - contrastive_accuracy: 0.0046 - val_loss: 2.4146 - val_classified_loss: 0.5745 - val_contrastive_loss: 2.6191 - val_classified_accuracy: 0.8364 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 21/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4341 - classified_loss: 0.6065 - contrastive_loss: 2.6372 - classified_accuracy: 0.8258 - contrastive_accuracy: 0.0042 - val_loss: 2.4122 - val_classified_loss: 0.5717 - val_contrastive_loss: 2.6167 - val_classified_accuracy: 0.8400 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 22/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4300 - classified_loss: 0.6019 - contrastive_loss: 2.6331 - classified_accuracy: 0.8311 - contrastive_accuracy: 0.0045 - val_loss: 2.4122 - val_classified_loss: 0.5694 - val_contrastive_loss: 2.6169 - val_classified_accuracy: 0.8390 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 23/200
# 243/243 [==============================] - 7s 27ms/step - loss: 2.4287 - classified_loss: 0.6010 - contrastive_loss: 2.6318 - classified_accuracy: 0.8287 - contrastive_accuracy: 0.0045 - val_loss: 2.4124 - val_classified_loss: 0.5728 - val_contrastive_loss: 2.6168 - val_classified_accuracy: 0.8380 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 24/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4349 - classified_loss: 0.6065 - contrastive_loss: 2.6381 - classified_accuracy: 0.8289 - contrastive_accuracy: 0.0039 - val_loss: 2.4104 - val_classified_loss: 0.5653 - val_contrastive_loss: 2.6154 - val_classified_accuracy: 0.8416 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 25/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4342 - classified_loss: 0.6059 - contrastive_loss: 2.6373 - classified_accuracy: 0.8273 - contrastive_accuracy: 0.0046 - val_loss: 2.4073 - val_classified_loss: 0.5688 - val_contrastive_loss: 2.6116 - val_classified_accuracy: 0.8411 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 26/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4321 - classified_loss: 0.6016 - contrastive_loss: 2.6355 - classified_accuracy: 0.8302 - contrastive_accuracy: 0.0046 - val_loss: 2.4213 - val_classified_loss: 0.5798 - val_contrastive_loss: 2.6259 - val_classified_accuracy: 0.8359 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 27/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4319 - classified_loss: 0.5973 - contrastive_loss: 2.6358 - classified_accuracy: 0.8280 - contrastive_accuracy: 0.0045 - val_loss: 2.4185 - val_classified_loss: 0.5811 - val_contrastive_loss: 2.6227 - val_classified_accuracy: 0.8364 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 28/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4347 - classified_loss: 0.5997 - contrastive_loss: 2.6386 - classified_accuracy: 0.8290 - contrastive_accuracy: 0.0043 - val_loss: 2.4225 - val_classified_loss: 0.5802 - val_contrastive_loss: 2.6273 - val_classified_accuracy: 0.8338 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 29/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4309 - classified_loss: 0.6010 - contrastive_loss: 2.6342 - classified_accuracy: 0.8286 - contrastive_accuracy: 0.0041 - val_loss: 2.4164 - val_classified_loss: 0.5764 - val_contrastive_loss: 2.6209 - val_classified_accuracy: 0.8354 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 30/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4329 - classified_loss: 0.6014 - contrastive_loss: 2.6364 - classified_accuracy: 0.8269 - contrastive_accuracy: 0.0046 - val_loss: 2.4137 - val_classified_loss: 0.5732 - val_contrastive_loss: 2.6182 - val_classified_accuracy: 0.8369 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 31/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4311 - classified_loss: 0.5999 - contrastive_loss: 2.6345 - classified_accuracy: 0.8271 - contrastive_accuracy: 0.0044 - val_loss: 2.4114 - val_classified_loss: 0.5687 - val_contrastive_loss: 2.6162 - val_classified_accuracy: 0.8400 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 32/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4234 - classified_loss: 0.5954 - contrastive_loss: 2.6265 - classified_accuracy: 0.8315 - contrastive_accuracy: 0.0043 - val_loss: 2.4117 - val_classified_loss: 0.5699 - val_contrastive_loss: 2.6164 - val_classified_accuracy: 0.8395 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 33/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4298 - classified_loss: 0.6019 - contrastive_loss: 2.6329 - classified_accuracy: 0.8291 - contrastive_accuracy: 0.0046 - val_loss: 2.4104 - val_classified_loss: 0.5670 - val_contrastive_loss: 2.6152 - val_classified_accuracy: 0.8421 - val_contrastive_accuracy: 0.0015 - lr: 1.0000e-04
# Epoch 34/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4281 - classified_loss: 0.5980 - contrastive_loss: 2.6314 - classified_accuracy: 0.8286 - contrastive_accuracy: 0.0043 - val_loss: 2.4115 - val_classified_loss: 0.5688 - val_contrastive_loss: 2.6162 - val_classified_accuracy: 0.8369 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 35/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4189 - classified_loss: 0.5903 - contrastive_loss: 2.6221 - classified_accuracy: 0.8332 - contrastive_accuracy: 0.0045 - val_loss: 2.4082 - val_classified_loss: 0.5660 - val_contrastive_loss: 2.6128 - val_classified_accuracy: 0.8406 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 36/200
# 243/243 [==============================] - 9s 36ms/step - loss: 2.4150 - classified_loss: 0.5914 - contrastive_loss: 2.6176 - classified_accuracy: 0.8358 - contrastive_accuracy: 0.0046 - val_loss: 2.4109 - val_classified_loss: 0.5647 - val_contrastive_loss: 2.6161 - val_classified_accuracy: 0.8390 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 37/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4149 - classified_loss: 0.5842 - contrastive_loss: 2.6183 - classified_accuracy: 0.8351 - contrastive_accuracy: 0.0037 - val_loss: 2.4105 - val_classified_loss: 0.5668 - val_contrastive_loss: 2.6153 - val_classified_accuracy: 0.8447 - val_contrastive_accuracy: 0.0015 - lr: 1.0000e-04
# Epoch 38/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4286 - classified_loss: 0.5946 - contrastive_loss: 2.6323 - classified_accuracy: 0.8314 - contrastive_accuracy: 0.0047 - val_loss: 2.3994 - val_classified_loss: 0.5560 - val_contrastive_loss: 2.6042 - val_classified_accuracy: 0.8431 - val_contrastive_accuracy: 0.0015 - lr: 1.0000e-04
# Epoch 39/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4214 - classified_loss: 0.5929 - contrastive_loss: 2.6245 - classified_accuracy: 0.8330 - contrastive_accuracy: 0.0043 - val_loss: 2.3996 - val_classified_loss: 0.5564 - val_contrastive_loss: 2.6044 - val_classified_accuracy: 0.8488 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 40/200
# 243/243 [==============================] - 5s 23ms/step - loss: 2.4168 - classified_loss: 0.5891 - contrastive_loss: 2.6199 - classified_accuracy: 0.8318 - contrastive_accuracy: 0.0045 - val_loss: 2.3914 - val_classified_loss: 0.5505 - val_contrastive_loss: 2.5959 - val_classified_accuracy: 0.8488 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 41/200
# 243/243 [==============================] - 6s 24ms/step - loss: 2.4206 - classified_loss: 0.5924 - contrastive_loss: 2.6238 - classified_accuracy: 0.8303 - contrastive_accuracy: 0.0047 - val_loss: 2.3947 - val_classified_loss: 0.5515 - val_contrastive_loss: 2.5995 - val_classified_accuracy: 0.8483 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 42/200
# 243/243 [==============================] - 7s 24ms/step - loss: 2.4178 - classified_loss: 0.5894 - contrastive_loss: 2.6209 - classified_accuracy: 0.8331 - contrastive_accuracy: 0.0045 - val_loss: 2.3899 - val_classified_loss: 0.5496 - val_contrastive_loss: 2.5944 - val_classified_accuracy: 0.8473 - val_contrastive_accuracy: 0.0015 - lr: 1.0000e-04
# Epoch 43/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4204 - classified_loss: 0.5912 - contrastive_loss: 2.6236 - classified_accuracy: 0.8325 - contrastive_accuracy: 0.0041 - val_loss: 2.3900 - val_classified_loss: 0.5494 - val_contrastive_loss: 2.5946 - val_classified_accuracy: 0.8514 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 44/200
# 243/243 [==============================] - 8s 30ms/step - loss: 2.4163 - classified_loss: 0.5914 - contrastive_loss: 2.6190 - classified_accuracy: 0.8334 - contrastive_accuracy: 0.0039 - val_loss: 2.3971 - val_classified_loss: 0.5556 - val_contrastive_loss: 2.6017 - val_classified_accuracy: 0.8467 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 45/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4197 - classified_loss: 0.5919 - contrastive_loss: 2.6228 - classified_accuracy: 0.8343 - contrastive_accuracy: 0.0051 - val_loss: 2.4019 - val_classified_loss: 0.5562 - val_contrastive_loss: 2.6070 - val_classified_accuracy: 0.8437 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 46/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4199 - classified_loss: 0.5912 - contrastive_loss: 2.6231 - classified_accuracy: 0.8331 - contrastive_accuracy: 0.0046 - val_loss: 2.3995 - val_classified_loss: 0.5562 - val_contrastive_loss: 2.6043 - val_classified_accuracy: 0.8483 - val_contrastive_accuracy: 0.0015 - lr: 1.0000e-04
# Epoch 47/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4166 - classified_loss: 0.5889 - contrastive_loss: 2.6197 - classified_accuracy: 0.8338 - contrastive_accuracy: 0.0046 - val_loss: 2.4043 - val_classified_loss: 0.5588 - val_contrastive_loss: 2.6093 - val_classified_accuracy: 0.8437 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 48/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4064 - classified_loss: 0.5793 - contrastive_loss: 2.6094 - classified_accuracy: 0.8360 - contrastive_accuracy: 0.0043 - val_loss: 2.4044 - val_classified_loss: 0.5643 - val_contrastive_loss: 2.6089 - val_classified_accuracy: 0.8437 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 49/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4190 - classified_loss: 0.5925 - contrastive_loss: 2.6220 - classified_accuracy: 0.8329 - contrastive_accuracy: 0.0041 - val_loss: 2.4071 - val_classified_loss: 0.5601 - val_contrastive_loss: 2.6123 - val_classified_accuracy: 0.8447 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 50/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4163 - classified_loss: 0.5876 - contrastive_loss: 2.6195 - classified_accuracy: 0.8355 - contrastive_accuracy: 0.0042 - val_loss: 2.4019 - val_classified_loss: 0.5607 - val_contrastive_loss: 2.6064 - val_classified_accuracy: 0.8478 - val_contrastive_accuracy: 0.0015 - lr: 1.0000e-04
# Epoch 51/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4228 - classified_loss: 0.5926 - contrastive_loss: 2.6262 - classified_accuracy: 0.8295 - contrastive_accuracy: 0.0047 - val_loss: 2.4073 - val_classified_loss: 0.5588 - val_contrastive_loss: 2.6127 - val_classified_accuracy: 0.8431 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 52/200
# 243/243 [==============================] - 7s 27ms/step - loss: 2.4147 - classified_loss: 0.5921 - contrastive_loss: 2.6172 - classified_accuracy: 0.8331 - contrastive_accuracy: 0.0038 - val_loss: 2.3989 - val_classified_loss: 0.5522 - val_contrastive_loss: 2.6041 - val_classified_accuracy: 0.8488 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 53/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4203 - classified_loss: 0.5910 - contrastive_loss: 2.6236 - classified_accuracy: 0.8332 - contrastive_accuracy: 0.0046 - val_loss: 2.4048 - val_classified_loss: 0.5589 - val_contrastive_loss: 2.6099 - val_classified_accuracy: 0.8467 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 54/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4174 - classified_loss: 0.5901 - contrastive_loss: 2.6204 - classified_accuracy: 0.8325 - contrastive_accuracy: 0.0047 - val_loss: 2.4062 - val_classified_loss: 0.5572 - val_contrastive_loss: 2.6116 - val_classified_accuracy: 0.8488 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 55/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4240 - classified_loss: 0.5903 - contrastive_loss: 2.6278 - classified_accuracy: 0.8308 - contrastive_accuracy: 0.0046 - val_loss: 2.4030 - val_classified_loss: 0.5522 - val_contrastive_loss: 2.6087 - val_classified_accuracy: 0.8431 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 56/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4207 - classified_loss: 0.5864 - contrastive_loss: 2.6245 - classified_accuracy: 0.8357 - contrastive_accuracy: 0.0039 - val_loss: 2.4049 - val_classified_loss: 0.5555 - val_contrastive_loss: 2.6104 - val_classified_accuracy: 0.8473 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 57/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4158 - classified_loss: 0.5849 - contrastive_loss: 2.6193 - classified_accuracy: 0.8350 - contrastive_accuracy: 0.0045 - val_loss: 2.4037 - val_classified_loss: 0.5559 - val_contrastive_loss: 2.6091 - val_classified_accuracy: 0.8483 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 58/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4076 - classified_loss: 0.5847 - contrastive_loss: 2.6101 - classified_accuracy: 0.8360 - contrastive_accuracy: 0.0039 - val_loss: 2.4014 - val_classified_loss: 0.5520 - val_contrastive_loss: 2.6069 - val_classified_accuracy: 0.8442 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 59/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4215 - classified_loss: 0.5855 - contrastive_loss: 2.6255 - classified_accuracy: 0.8363 - contrastive_accuracy: 0.0045 - val_loss: 2.4076 - val_classified_loss: 0.5607 - val_contrastive_loss: 2.6128 - val_classified_accuracy: 0.8406 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 60/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4236 - classified_loss: 0.5928 - contrastive_loss: 2.6271 - classified_accuracy: 0.8314 - contrastive_accuracy: 0.0046 - val_loss: 2.4073 - val_classified_loss: 0.5619 - val_contrastive_loss: 2.6124 - val_classified_accuracy: 0.8395 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 61/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4182 - classified_loss: 0.5831 - contrastive_loss: 2.6221 - classified_accuracy: 0.8314 - contrastive_accuracy: 0.0046 - val_loss: 2.4064 - val_classified_loss: 0.5589 - val_contrastive_loss: 2.6117 - val_classified_accuracy: 0.8473 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 62/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4187 - classified_loss: 0.5870 - contrastive_loss: 2.6222 - classified_accuracy: 0.8336 - contrastive_accuracy: 0.0048 - val_loss: 2.4030 - val_classified_loss: 0.5612 - val_contrastive_loss: 2.6076 - val_classified_accuracy: 0.8462 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 63/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4120 - classified_loss: 0.5854 - contrastive_loss: 2.6150 - classified_accuracy: 0.8353 - contrastive_accuracy: 0.0044 - val_loss: 2.4032 - val_classified_loss: 0.5601 - val_contrastive_loss: 2.6080 - val_classified_accuracy: 0.8431 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 64/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4114 - classified_loss: 0.5835 - contrastive_loss: 2.6145 - classified_accuracy: 0.8351 - contrastive_accuracy: 0.0046 - val_loss: 2.4032 - val_classified_loss: 0.5591 - val_contrastive_loss: 2.6080 - val_classified_accuracy: 0.8488 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 65/200
# 243/243 [==============================] - 9s 35ms/step - loss: 2.4027 - classified_loss: 0.5780 - contrastive_loss: 2.6055 - classified_accuracy: 0.8356 - contrastive_accuracy: 0.0045 - val_loss: 2.3937 - val_classified_loss: 0.5522 - val_contrastive_loss: 2.5983 - val_classified_accuracy: 0.8457 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 66/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4094 - classified_loss: 0.5829 - contrastive_loss: 2.6123 - classified_accuracy: 0.8359 - contrastive_accuracy: 0.0050 - val_loss: 2.3934 - val_classified_loss: 0.5536 - val_contrastive_loss: 2.5978 - val_classified_accuracy: 0.8473 - val_contrastive_accuracy: 0.0015 - lr: 1.0000e-04
# Epoch 67/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4108 - classified_loss: 0.5761 - contrastive_loss: 2.6147 - classified_accuracy: 0.8374 - contrastive_accuracy: 0.0038 - val_loss: 2.3885 - val_classified_loss: 0.5497 - val_contrastive_loss: 2.5928 - val_classified_accuracy: 0.8498 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 68/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4036 - classified_loss: 0.5809 - contrastive_loss: 2.6061 - classified_accuracy: 0.8368 - contrastive_accuracy: 0.0046 - val_loss: 2.3917 - val_classified_loss: 0.5495 - val_contrastive_loss: 2.5964 - val_classified_accuracy: 0.8457 - val_contrastive_accuracy: 0.0046 - lr: 1.0000e-04
# Epoch 69/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4056 - classified_loss: 0.5761 - contrastive_loss: 2.6088 - classified_accuracy: 0.8349 - contrastive_accuracy: 0.0041 - val_loss: 2.3887 - val_classified_loss: 0.5437 - val_contrastive_loss: 2.5937 - val_classified_accuracy: 0.8493 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 70/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4084 - classified_loss: 0.5800 - contrastive_loss: 2.6116 - classified_accuracy: 0.8383 - contrastive_accuracy: 0.0041 - val_loss: 2.3971 - val_classified_loss: 0.5558 - val_contrastive_loss: 2.6017 - val_classified_accuracy: 0.8457 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 71/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4074 - classified_loss: 0.5745 - contrastive_loss: 2.6110 - classified_accuracy: 0.8377 - contrastive_accuracy: 0.0045 - val_loss: 2.3981 - val_classified_loss: 0.5583 - val_contrastive_loss: 2.6025 - val_classified_accuracy: 0.8462 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 72/200
# 243/243 [==============================] - 8s 29ms/step - loss: 2.4113 - classified_loss: 0.5800 - contrastive_loss: 2.6147 - classified_accuracy: 0.8368 - contrastive_accuracy: 0.0043 - val_loss: 2.3903 - val_classified_loss: 0.5489 - val_contrastive_loss: 2.5949 - val_classified_accuracy: 0.8473 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 73/200
# 243/243 [==============================] - 6s 24ms/step - loss: 2.4125 - classified_loss: 0.5864 - contrastive_loss: 2.6154 - classified_accuracy: 0.8336 - contrastive_accuracy: 0.0039 - val_loss: 2.3934 - val_classified_loss: 0.5497 - val_contrastive_loss: 2.5983 - val_classified_accuracy: 0.8467 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 74/200
# 243/243 [==============================] - 6s 24ms/step - loss: 2.4089 - classified_loss: 0.5813 - contrastive_loss: 2.6120 - classified_accuracy: 0.8367 - contrastive_accuracy: 0.0040 - val_loss: 2.3936 - val_classified_loss: 0.5503 - val_contrastive_loss: 2.5984 - val_classified_accuracy: 0.8462 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 75/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4065 - classified_loss: 0.5844 - contrastive_loss: 2.6090 - classified_accuracy: 0.8368 - contrastive_accuracy: 0.0042 - val_loss: 2.3919 - val_classified_loss: 0.5509 - val_contrastive_loss: 2.5964 - val_classified_accuracy: 0.8442 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 76/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4081 - classified_loss: 0.5844 - contrastive_loss: 2.6107 - classified_accuracy: 0.8367 - contrastive_accuracy: 0.0036 - val_loss: 2.3937 - val_classified_loss: 0.5550 - val_contrastive_loss: 2.5980 - val_classified_accuracy: 0.8509 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 77/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4006 - classified_loss: 0.5797 - contrastive_loss: 2.6029 - classified_accuracy: 0.8381 - contrastive_accuracy: 0.0043 - val_loss: 2.3994 - val_classified_loss: 0.5613 - val_contrastive_loss: 2.6037 - val_classified_accuracy: 0.8406 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 78/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4089 - classified_loss: 0.5803 - contrastive_loss: 2.6121 - classified_accuracy: 0.8371 - contrastive_accuracy: 0.0043 - val_loss: 2.3933 - val_classified_loss: 0.5514 - val_contrastive_loss: 2.5980 - val_classified_accuracy: 0.8509 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 79/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4022 - classified_loss: 0.5700 - contrastive_loss: 2.6058 - classified_accuracy: 0.8389 - contrastive_accuracy: 0.0040 - val_loss: 2.3899 - val_classified_loss: 0.5509 - val_contrastive_loss: 2.5942 - val_classified_accuracy: 0.8493 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 80/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4004 - classified_loss: 0.5760 - contrastive_loss: 2.6031 - classified_accuracy: 0.8370 - contrastive_accuracy: 0.0050 - val_loss: 2.3914 - val_classified_loss: 0.5478 - val_contrastive_loss: 2.5962 - val_classified_accuracy: 0.8467 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 81/200
# 243/243 [==============================] - 5s 22ms/step - loss: 2.4096 - classified_loss: 0.5809 - contrastive_loss: 2.6128 - classified_accuracy: 0.8382 - contrastive_accuracy: 0.0043 - val_loss: 2.3931 - val_classified_loss: 0.5502 - val_contrastive_loss: 2.5979 - val_classified_accuracy: 0.8504 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 82/200
# 243/243 [==============================] - 6s 25ms/step - loss: 2.4088 - classified_loss: 0.5808 - contrastive_loss: 2.6119 - classified_accuracy: 0.8377 - contrastive_accuracy: 0.0045 - val_loss: 2.3939 - val_classified_loss: 0.5528 - val_contrastive_loss: 2.5984 - val_classified_accuracy: 0.8473 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 83/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4136 - classified_loss: 0.5784 - contrastive_loss: 2.6175 - classified_accuracy: 0.8354 - contrastive_accuracy: 0.0043 - val_loss: 2.3949 - val_classified_loss: 0.5506 - val_contrastive_loss: 2.5999 - val_classified_accuracy: 0.8457 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 84/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4028 - classified_loss: 0.5802 - contrastive_loss: 2.6054 - classified_accuracy: 0.8385 - contrastive_accuracy: 0.0039 - val_loss: 2.4010 - val_classified_loss: 0.5599 - val_contrastive_loss: 2.6055 - val_classified_accuracy: 0.8447 - val_contrastive_accuracy: 0.0015 - lr: 1.0000e-04
# Epoch 85/200
# 243/243 [==============================] - 7s 31ms/step - loss: 2.4080 - classified_loss: 0.5844 - contrastive_loss: 2.6107 - classified_accuracy: 0.8333 - contrastive_accuracy: 0.0039 - val_loss: 2.3903 - val_classified_loss: 0.5444 - val_contrastive_loss: 2.5954 - val_classified_accuracy: 0.8514 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 86/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4107 - classified_loss: 0.5842 - contrastive_loss: 2.6137 - classified_accuracy: 0.8362 - contrastive_accuracy: 0.0038 - val_loss: 2.3901 - val_classified_loss: 0.5492 - val_contrastive_loss: 2.5946 - val_classified_accuracy: 0.8467 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 87/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4082 - classified_loss: 0.5822 - contrastive_loss: 2.6111 - classified_accuracy: 0.8367 - contrastive_accuracy: 0.0041 - val_loss: 2.3852 - val_classified_loss: 0.5468 - val_contrastive_loss: 2.5895 - val_classified_accuracy: 0.8467 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 88/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4139 - classified_loss: 0.5809 - contrastive_loss: 2.6176 - classified_accuracy: 0.8354 - contrastive_accuracy: 0.0046 - val_loss: 2.3942 - val_classified_loss: 0.5522 - val_contrastive_loss: 2.5989 - val_classified_accuracy: 0.8473 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 89/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4055 - classified_loss: 0.5775 - contrastive_loss: 2.6086 - classified_accuracy: 0.8392 - contrastive_accuracy: 0.0039 - val_loss: 2.3858 - val_classified_loss: 0.5432 - val_contrastive_loss: 2.5905 - val_classified_accuracy: 0.8478 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 90/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4021 - classified_loss: 0.5723 - contrastive_loss: 2.6055 - classified_accuracy: 0.8389 - contrastive_accuracy: 0.0045 - val_loss: 2.3850 - val_classified_loss: 0.5398 - val_contrastive_loss: 2.5901 - val_classified_accuracy: 0.8462 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 91/200
# 243/243 [==============================] - 9s 31ms/step - loss: 2.4079 - classified_loss: 0.5752 - contrastive_loss: 2.6115 - classified_accuracy: 0.8389 - contrastive_accuracy: 0.0041 - val_loss: 2.3832 - val_classified_loss: 0.5395 - val_contrastive_loss: 2.5881 - val_classified_accuracy: 0.8483 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 92/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4082 - classified_loss: 0.5787 - contrastive_loss: 2.6115 - classified_accuracy: 0.8386 - contrastive_accuracy: 0.0036 - val_loss: 2.3910 - val_classified_loss: 0.5446 - val_contrastive_loss: 2.5962 - val_classified_accuracy: 0.8488 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 93/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4077 - classified_loss: 0.5786 - contrastive_loss: 2.6109 - classified_accuracy: 0.8376 - contrastive_accuracy: 0.0043 - val_loss: 2.3854 - val_classified_loss: 0.5379 - val_contrastive_loss: 2.5907 - val_classified_accuracy: 0.8493 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 94/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4036 - classified_loss: 0.5796 - contrastive_loss: 2.6062 - classified_accuracy: 0.8379 - contrastive_accuracy: 0.0039 - val_loss: 2.3935 - val_classified_loss: 0.5485 - val_contrastive_loss: 2.5984 - val_classified_accuracy: 0.8488 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 95/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4096 - classified_loss: 0.5786 - contrastive_loss: 2.6131 - classified_accuracy: 0.8374 - contrastive_accuracy: 0.0036 - val_loss: 2.3915 - val_classified_loss: 0.5484 - val_contrastive_loss: 2.5963 - val_classified_accuracy: 0.8493 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 96/200
# 243/243 [==============================] - 6s 27ms/step - loss: 2.3984 - classified_loss: 0.5743 - contrastive_loss: 2.6011 - classified_accuracy: 0.8389 - contrastive_accuracy: 0.0036 - val_loss: 2.3904 - val_classified_loss: 0.5447 - val_contrastive_loss: 2.5955 - val_classified_accuracy: 0.8524 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 97/200
# 243/243 [==============================] - 6s 24ms/step - loss: 2.4002 - classified_loss: 0.5712 - contrastive_loss: 2.6035 - classified_accuracy: 0.8393 - contrastive_accuracy: 0.0041 - val_loss: 2.3850 - val_classified_loss: 0.5406 - val_contrastive_loss: 2.5899 - val_classified_accuracy: 0.8540 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 98/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4057 - classified_loss: 0.5767 - contrastive_loss: 2.6089 - classified_accuracy: 0.8381 - contrastive_accuracy: 0.0039 - val_loss: 2.3821 - val_classified_loss: 0.5348 - val_contrastive_loss: 2.5874 - val_classified_accuracy: 0.8529 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 99/200
# 243/243 [==============================] - 7s 31ms/step - loss: 2.3979 - classified_loss: 0.5735 - contrastive_loss: 2.6006 - classified_accuracy: 0.8409 - contrastive_accuracy: 0.0037 - val_loss: 2.3777 - val_classified_loss: 0.5352 - val_contrastive_loss: 2.5824 - val_classified_accuracy: 0.8540 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 100/200
# 243/243 [==============================] - 6s 24ms/step - loss: 2.4002 - classified_loss: 0.5769 - contrastive_loss: 2.6028 - classified_accuracy: 0.8398 - contrastive_accuracy: 0.0035 - val_loss: 2.3788 - val_classified_loss: 0.5338 - val_contrastive_loss: 2.5838 - val_classified_accuracy: 0.8566 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 101/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.3967 - classified_loss: 0.5651 - contrastive_loss: 2.6002 - classified_accuracy: 0.8385 - contrastive_accuracy: 0.0042 - val_loss: 2.3764 - val_classified_loss: 0.5359 - val_contrastive_loss: 2.5809 - val_classified_accuracy: 0.8529 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 102/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4031 - classified_loss: 0.5728 - contrastive_loss: 2.6065 - classified_accuracy: 0.8412 - contrastive_accuracy: 0.0041 - val_loss: 2.3865 - val_classified_loss: 0.5432 - val_contrastive_loss: 2.5913 - val_classified_accuracy: 0.8545 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 103/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4025 - classified_loss: 0.5730 - contrastive_loss: 2.6058 - classified_accuracy: 0.8382 - contrastive_accuracy: 0.0045 - val_loss: 2.3906 - val_classified_loss: 0.5499 - val_contrastive_loss: 2.5951 - val_classified_accuracy: 0.8514 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 104/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.3998 - classified_loss: 0.5725 - contrastive_loss: 2.6029 - classified_accuracy: 0.8398 - contrastive_accuracy: 0.0045 - val_loss: 2.3843 - val_classified_loss: 0.5430 - val_contrastive_loss: 2.5889 - val_classified_accuracy: 0.8529 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 105/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3964 - classified_loss: 0.5695 - contrastive_loss: 2.5993 - classified_accuracy: 0.8384 - contrastive_accuracy: 0.0045 - val_loss: 2.3849 - val_classified_loss: 0.5453 - val_contrastive_loss: 2.5892 - val_classified_accuracy: 0.8519 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 106/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.4032 - classified_loss: 0.5697 - contrastive_loss: 2.6069 - classified_accuracy: 0.8427 - contrastive_accuracy: 0.0044 - val_loss: 2.3860 - val_classified_loss: 0.5463 - val_contrastive_loss: 2.5904 - val_classified_accuracy: 0.8509 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 107/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4044 - classified_loss: 0.5715 - contrastive_loss: 2.6080 - classified_accuracy: 0.8370 - contrastive_accuracy: 0.0041 - val_loss: 2.3832 - val_classified_loss: 0.5425 - val_contrastive_loss: 2.5877 - val_classified_accuracy: 0.8519 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 108/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3954 - classified_loss: 0.5694 - contrastive_loss: 2.5982 - classified_accuracy: 0.8414 - contrastive_accuracy: 0.0044 - val_loss: 2.3854 - val_classified_loss: 0.5425 - val_contrastive_loss: 2.5901 - val_classified_accuracy: 0.8529 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 109/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.4014 - classified_loss: 0.5721 - contrastive_loss: 2.6047 - classified_accuracy: 0.8400 - contrastive_accuracy: 0.0040 - val_loss: 2.3812 - val_classified_loss: 0.5378 - val_contrastive_loss: 2.5861 - val_classified_accuracy: 0.8509 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 110/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.3973 - classified_loss: 0.5729 - contrastive_loss: 2.6000 - classified_accuracy: 0.8392 - contrastive_accuracy: 0.0041 - val_loss: 2.3879 - val_classified_loss: 0.5468 - val_contrastive_loss: 2.5924 - val_classified_accuracy: 0.8473 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 111/200
# 243/243 [==============================] - 7s 27ms/step - loss: 2.3972 - classified_loss: 0.5648 - contrastive_loss: 2.6008 - classified_accuracy: 0.8416 - contrastive_accuracy: 0.0042 - val_loss: 2.3879 - val_classified_loss: 0.5453 - val_contrastive_loss: 2.5927 - val_classified_accuracy: 0.8519 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 112/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4010 - classified_loss: 0.5684 - contrastive_loss: 2.6046 - classified_accuracy: 0.8412 - contrastive_accuracy: 0.0049 - val_loss: 2.3881 - val_classified_loss: 0.5445 - val_contrastive_loss: 2.5929 - val_classified_accuracy: 0.8493 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 113/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.3909 - classified_loss: 0.5639 - contrastive_loss: 2.5939 - classified_accuracy: 0.8413 - contrastive_accuracy: 0.0043 - val_loss: 2.3845 - val_classified_loss: 0.5419 - val_contrastive_loss: 2.5893 - val_classified_accuracy: 0.8519 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 114/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4009 - classified_loss: 0.5728 - contrastive_loss: 2.6041 - classified_accuracy: 0.8399 - contrastive_accuracy: 0.0046 - val_loss: 2.3854 - val_classified_loss: 0.5411 - val_contrastive_loss: 2.5903 - val_classified_accuracy: 0.8509 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 115/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.3992 - classified_loss: 0.5729 - contrastive_loss: 2.6021 - classified_accuracy: 0.8384 - contrastive_accuracy: 0.0041 - val_loss: 2.3818 - val_classified_loss: 0.5434 - val_contrastive_loss: 2.5860 - val_classified_accuracy: 0.8540 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 116/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.4049 - classified_loss: 0.5764 - contrastive_loss: 2.6081 - classified_accuracy: 0.8393 - contrastive_accuracy: 0.0041 - val_loss: 2.3839 - val_classified_loss: 0.5436 - val_contrastive_loss: 2.5884 - val_classified_accuracy: 0.8555 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 117/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.4004 - classified_loss: 0.5703 - contrastive_loss: 2.6037 - classified_accuracy: 0.8409 - contrastive_accuracy: 0.0039 - val_loss: 2.3891 - val_classified_loss: 0.5453 - val_contrastive_loss: 2.5939 - val_classified_accuracy: 0.8540 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 118/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.3977 - classified_loss: 0.5689 - contrastive_loss: 2.6009 - classified_accuracy: 0.8407 - contrastive_accuracy: 0.0046 - val_loss: 2.3806 - val_classified_loss: 0.5402 - val_contrastive_loss: 2.5851 - val_classified_accuracy: 0.8504 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 119/200
# 243/243 [==============================] - 8s 30ms/step - loss: 2.3977 - classified_loss: 0.5682 - contrastive_loss: 2.6009 - classified_accuracy: 0.8415 - contrastive_accuracy: 0.0045 - val_loss: 2.3841 - val_classified_loss: 0.5449 - val_contrastive_loss: 2.5884 - val_classified_accuracy: 0.8504 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 120/200
# 243/243 [==============================] - 7s 31ms/step - loss: 2.3988 - classified_loss: 0.5666 - contrastive_loss: 2.6023 - classified_accuracy: 0.8410 - contrastive_accuracy: 0.0043 - val_loss: 2.3822 - val_classified_loss: 0.5428 - val_contrastive_loss: 2.5866 - val_classified_accuracy: 0.8519 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 121/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.3975 - classified_loss: 0.5694 - contrastive_loss: 2.6006 - classified_accuracy: 0.8394 - contrastive_accuracy: 0.0050 - val_loss: 2.3743 - val_classified_loss: 0.5383 - val_contrastive_loss: 2.5783 - val_classified_accuracy: 0.8535 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 122/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3931 - classified_loss: 0.5649 - contrastive_loss: 2.5963 - classified_accuracy: 0.8439 - contrastive_accuracy: 0.0037 - val_loss: 2.3752 - val_classified_loss: 0.5379 - val_contrastive_loss: 2.5794 - val_classified_accuracy: 0.8550 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 123/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3954 - classified_loss: 0.5681 - contrastive_loss: 2.5985 - classified_accuracy: 0.8413 - contrastive_accuracy: 0.0039 - val_loss: 2.3777 - val_classified_loss: 0.5384 - val_contrastive_loss: 2.5820 - val_classified_accuracy: 0.8545 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 124/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3915 - classified_loss: 0.5634 - contrastive_loss: 2.5946 - classified_accuracy: 0.8417 - contrastive_accuracy: 0.0045 - val_loss: 2.3760 - val_classified_loss: 0.5335 - val_contrastive_loss: 2.5807 - val_classified_accuracy: 0.8555 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 125/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3948 - classified_loss: 0.5676 - contrastive_loss: 2.5978 - classified_accuracy: 0.8424 - contrastive_accuracy: 0.0043 - val_loss: 2.3779 - val_classified_loss: 0.5381 - val_contrastive_loss: 2.5823 - val_classified_accuracy: 0.8560 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 126/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.3911 - classified_loss: 0.5629 - contrastive_loss: 2.5943 - classified_accuracy: 0.8425 - contrastive_accuracy: 0.0043 - val_loss: 2.3730 - val_classified_loss: 0.5300 - val_contrastive_loss: 2.5778 - val_classified_accuracy: 0.8529 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 127/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.3911 - classified_loss: 0.5663 - contrastive_loss: 2.5939 - classified_accuracy: 0.8412 - contrastive_accuracy: 0.0041 - val_loss: 2.3759 - val_classified_loss: 0.5340 - val_contrastive_loss: 2.5806 - val_classified_accuracy: 0.8566 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 128/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.3904 - classified_loss: 0.5664 - contrastive_loss: 2.5930 - classified_accuracy: 0.8433 - contrastive_accuracy: 0.0037 - val_loss: 2.3800 - val_classified_loss: 0.5396 - val_contrastive_loss: 2.5845 - val_classified_accuracy: 0.8529 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 129/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.3937 - classified_loss: 0.5682 - contrastive_loss: 2.5965 - classified_accuracy: 0.8447 - contrastive_accuracy: 0.0044 - val_loss: 2.3693 - val_classified_loss: 0.5260 - val_contrastive_loss: 2.5742 - val_classified_accuracy: 0.8566 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 130/200
# 243/243 [==============================] - 7s 27ms/step - loss: 2.3908 - classified_loss: 0.5657 - contrastive_loss: 2.5935 - classified_accuracy: 0.8431 - contrastive_accuracy: 0.0045 - val_loss: 2.3670 - val_classified_loss: 0.5291 - val_contrastive_loss: 2.5712 - val_classified_accuracy: 0.8576 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 131/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.3997 - classified_loss: 0.5692 - contrastive_loss: 2.6030 - classified_accuracy: 0.8416 - contrastive_accuracy: 0.0040 - val_loss: 2.3665 - val_classified_loss: 0.5259 - val_contrastive_loss: 2.5710 - val_classified_accuracy: 0.8576 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 132/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3930 - classified_loss: 0.5590 - contrastive_loss: 2.5968 - classified_accuracy: 0.8453 - contrastive_accuracy: 0.0049 - val_loss: 2.3622 - val_classified_loss: 0.5252 - val_contrastive_loss: 2.5663 - val_classified_accuracy: 0.8586 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 133/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.3911 - classified_loss: 0.5650 - contrastive_loss: 2.5940 - classified_accuracy: 0.8422 - contrastive_accuracy: 0.0039 - val_loss: 2.3731 - val_classified_loss: 0.5324 - val_contrastive_loss: 2.5776 - val_classified_accuracy: 0.8545 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 134/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.3983 - classified_loss: 0.5702 - contrastive_loss: 2.6015 - classified_accuracy: 0.8421 - contrastive_accuracy: 0.0041 - val_loss: 2.3695 - val_classified_loss: 0.5323 - val_contrastive_loss: 2.5737 - val_classified_accuracy: 0.8550 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 135/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.3863 - classified_loss: 0.5557 - contrastive_loss: 2.5897 - classified_accuracy: 0.8443 - contrastive_accuracy: 0.0040 - val_loss: 2.3697 - val_classified_loss: 0.5294 - val_contrastive_loss: 2.5741 - val_classified_accuracy: 0.8555 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 136/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3962 - classified_loss: 0.5629 - contrastive_loss: 2.5999 - classified_accuracy: 0.8427 - contrastive_accuracy: 0.0044 - val_loss: 2.3679 - val_classified_loss: 0.5281 - val_contrastive_loss: 2.5724 - val_classified_accuracy: 0.8550 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 137/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.3860 - classified_loss: 0.5617 - contrastive_loss: 2.5887 - classified_accuracy: 0.8438 - contrastive_accuracy: 0.0045 - val_loss: 2.3672 - val_classified_loss: 0.5252 - val_contrastive_loss: 2.5719 - val_classified_accuracy: 0.8581 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 138/200
# 243/243 [==============================] - 7s 27ms/step - loss: 2.3951 - classified_loss: 0.5660 - contrastive_loss: 2.5983 - classified_accuracy: 0.8430 - contrastive_accuracy: 0.0050 - val_loss: 2.3702 - val_classified_loss: 0.5292 - val_contrastive_loss: 2.5748 - val_classified_accuracy: 0.8524 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 139/200
# 243/243 [==============================] - 8s 33ms/step - loss: 2.3897 - classified_loss: 0.5598 - contrastive_loss: 2.5930 - classified_accuracy: 0.8446 - contrastive_accuracy: 0.0039 - val_loss: 2.3734 - val_classified_loss: 0.5338 - val_contrastive_loss: 2.5778 - val_classified_accuracy: 0.8509 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 140/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.3866 - classified_loss: 0.5635 - contrastive_loss: 2.5892 - classified_accuracy: 0.8424 - contrastive_accuracy: 0.0045 - val_loss: 2.3711 - val_classified_loss: 0.5300 - val_contrastive_loss: 2.5757 - val_classified_accuracy: 0.8540 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 141/200
# 243/243 [==============================] - 6s 25ms/step - loss: 2.3885 - classified_loss: 0.5576 - contrastive_loss: 2.5919 - classified_accuracy: 0.8452 - contrastive_accuracy: 0.0046 - val_loss: 2.3699 - val_classified_loss: 0.5310 - val_contrastive_loss: 2.5742 - val_classified_accuracy: 0.8550 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 142/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3894 - classified_loss: 0.5593 - contrastive_loss: 2.5927 - classified_accuracy: 0.8440 - contrastive_accuracy: 0.0042 - val_loss: 2.3685 - val_classified_loss: 0.5250 - val_contrastive_loss: 2.5734 - val_classified_accuracy: 0.8571 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 143/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.3899 - classified_loss: 0.5597 - contrastive_loss: 2.5932 - classified_accuracy: 0.8461 - contrastive_accuracy: 0.0043 - val_loss: 2.3710 - val_classified_loss: 0.5289 - val_contrastive_loss: 2.5757 - val_classified_accuracy: 0.8576 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 144/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.3906 - classified_loss: 0.5560 - contrastive_loss: 2.5945 - classified_accuracy: 0.8426 - contrastive_accuracy: 0.0040 - val_loss: 2.3703 - val_classified_loss: 0.5298 - val_contrastive_loss: 2.5748 - val_classified_accuracy: 0.8586 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 145/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.3907 - classified_loss: 0.5577 - contrastive_loss: 2.5944 - classified_accuracy: 0.8441 - contrastive_accuracy: 0.0040 - val_loss: 2.3642 - val_classified_loss: 0.5203 - val_contrastive_loss: 2.5691 - val_classified_accuracy: 0.8596 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 146/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3881 - classified_loss: 0.5547 - contrastive_loss: 2.5918 - classified_accuracy: 0.8476 - contrastive_accuracy: 0.0042 - val_loss: 2.3621 - val_classified_loss: 0.5156 - val_contrastive_loss: 2.5673 - val_classified_accuracy: 0.8612 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 147/200
# 243/243 [==============================] - 7s 31ms/step - loss: 2.3914 - classified_loss: 0.5559 - contrastive_loss: 2.5953 - classified_accuracy: 0.8467 - contrastive_accuracy: 0.0043 - val_loss: 2.3635 - val_classified_loss: 0.5169 - val_contrastive_loss: 2.5687 - val_classified_accuracy: 0.8596 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 148/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.3842 - classified_loss: 0.5575 - contrastive_loss: 2.5872 - classified_accuracy: 0.8451 - contrastive_accuracy: 0.0043 - val_loss: 2.3692 - val_classified_loss: 0.5260 - val_contrastive_loss: 2.5740 - val_classified_accuracy: 0.8555 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 149/200
# 243/243 [==============================] - 7s 31ms/step - loss: 2.3779 - classified_loss: 0.5526 - contrastive_loss: 2.5807 - classified_accuracy: 0.8471 - contrastive_accuracy: 0.0042 - val_loss: 2.3727 - val_classified_loss: 0.5299 - val_contrastive_loss: 2.5775 - val_classified_accuracy: 0.8535 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 150/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.3854 - classified_loss: 0.5508 - contrastive_loss: 2.5892 - classified_accuracy: 0.8465 - contrastive_accuracy: 0.0040 - val_loss: 2.3699 - val_classified_loss: 0.5261 - val_contrastive_loss: 2.5748 - val_classified_accuracy: 0.8535 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 151/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.3879 - classified_loss: 0.5539 - contrastive_loss: 2.5916 - classified_accuracy: 0.8476 - contrastive_accuracy: 0.0045 - val_loss: 2.3681 - val_classified_loss: 0.5252 - val_contrastive_loss: 2.5729 - val_classified_accuracy: 0.8576 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 152/200
# 243/243 [==============================] - 8s 32ms/step - loss: 2.3855 - classified_loss: 0.5504 - contrastive_loss: 2.5894 - classified_accuracy: 0.8481 - contrastive_accuracy: 0.0043 - val_loss: 2.3670 - val_classified_loss: 0.5265 - val_contrastive_loss: 2.5715 - val_classified_accuracy: 0.8560 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 153/200
# 243/243 [==============================] - 8s 31ms/step - loss: 2.3845 - classified_loss: 0.5521 - contrastive_loss: 2.5881 - classified_accuracy: 0.8482 - contrastive_accuracy: 0.0047 - val_loss: 2.3628 - val_classified_loss: 0.5205 - val_contrastive_loss: 2.5675 - val_classified_accuracy: 0.8617 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 154/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.3802 - classified_loss: 0.5543 - contrastive_loss: 2.5831 - classified_accuracy: 0.8434 - contrastive_accuracy: 0.0046 - val_loss: 2.3659 - val_classified_loss: 0.5257 - val_contrastive_loss: 2.5704 - val_classified_accuracy: 0.8566 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 155/200
# 243/243 [==============================] - 7s 28ms/step - loss: 2.3820 - classified_loss: 0.5577 - contrastive_loss: 2.5848 - classified_accuracy: 0.8445 - contrastive_accuracy: 0.0044 - val_loss: 2.3601 - val_classified_loss: 0.5229 - val_contrastive_loss: 2.5642 - val_classified_accuracy: 0.8571 - val_contrastive_accuracy: 0.0036 - lr: 1.0000e-04
# Epoch 156/200
# 243/243 [==============================] - 6s 25ms/step - loss: 2.3758 - classified_loss: 0.5511 - contrastive_loss: 2.5785 - classified_accuracy: 0.8485 - contrastive_accuracy: 0.0041 - val_loss: 2.3619 - val_classified_loss: 0.5260 - val_contrastive_loss: 2.5659 - val_classified_accuracy: 0.8581 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 157/200
# 243/243 [==============================] - 7s 27ms/step - loss: 2.3823 - classified_loss: 0.5504 - contrastive_loss: 2.5859 - classified_accuracy: 0.8463 - contrastive_accuracy: 0.0039 - val_loss: 2.3607 - val_classified_loss: 0.5214 - val_contrastive_loss: 2.5651 - val_classified_accuracy: 0.8591 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 158/200
# 243/243 [==============================] - 6s 23ms/step - loss: 2.3856 - classified_loss: 0.5518 - contrastive_loss: 2.5893 - classified_accuracy: 0.8480 - contrastive_accuracy: 0.0045 - val_loss: 2.3603 - val_classified_loss: 0.5249 - val_contrastive_loss: 2.5643 - val_classified_accuracy: 0.8566 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 159/200
# 243/243 [==============================] - 6s 27ms/step - loss: 2.3773 - classified_loss: 0.5519 - contrastive_loss: 2.5801 - classified_accuracy: 0.8474 - contrastive_accuracy: 0.0043 - val_loss: 2.3558 - val_classified_loss: 0.5163 - val_contrastive_loss: 2.5602 - val_classified_accuracy: 0.8576 - val_contrastive_accuracy: 0.0031 - lr: 1.0000e-04
# Epoch 160/200
# 243/243 [==============================] - 7s 29ms/step - loss: 2.3816 - classified_loss: 0.5538 - contrastive_loss: 2.5847 - classified_accuracy: 0.8453 - contrastive_accuracy: 0.0043 - val_loss: 2.3569 - val_classified_loss: 0.5213 - val_contrastive_loss: 2.5608 - val_classified_accuracy: 0.8545 - val_contrastive_accuracy: 0.0021 - lr: 1.0000e-04
# Epoch 161/200
# 243/243 [==============================] - 7s 30ms/step - loss: 2.3792 - classified_loss: 0.5530 - contrastive_loss: 2.5821 - classified_accuracy: 0.8479 - contrastive_accuracy: 0.0041 - val_loss: 2.3661 - val_classified_loss: 0.5224 - val_contrastive_loss: 2.5709 - val_classified_accuracy: 0.8566 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 162/200
# 243/243 [==============================] - 7s 31ms/step - loss: 2.3775 - classified_loss: 0.5508 - contrastive_loss: 2.5805 - classified_accuracy: 0.8481 - contrastive_accuracy: 0.0046 - val_loss: 2.3605 - val_classified_loss: 0.5256 - val_contrastive_loss: 2.5644 - val_classified_accuracy: 0.8581 - val_contrastive_accuracy: 0.0026 - lr: 1.0000e-04
# Epoch 163/200
# 243/243 [==============================] - ETA: 0s - loss: 2.3776 - classified_loss: 0.5482 - contrastive_loss: 2.5809 - classified_accuracy: 0.8488 - contrastive_accuracy: 0.0047

# %%
# epoch of the minimum valid loss
min(range(len(history.history['val_classified_loss'])), key=lambda i: history.history['val_classified_loss'][i])
# Out:
# 98

# %%
def plot_training_loss_balancing(H, plotPath):
    	# construct a plot that plots and saves the training history
	plt.style.use("ggplot")
	plt.figure()
	plt.plot(H.history["classified_loss"], label="train_loss")
	plt.plot(H.history["val_classified_loss"], label="val_loss")
	plt.title("Training Loss")
	plt.xlabel("Epoch #")
	plt.ylabel("Loss")
	plt.legend(loc="lower left")
	if plotPath is not None:
		plt.savefig(plotPath)
	else:
		plt.show()

def plot_training_acc_balancing(H, plotPath):
    	# construct a plot that plots and saves the training history
	plt.style.use("ggplot")
	plt.figure()
	plt.plot(H.history["classified_accuracy"], label="train_accuracy")
	plt.plot(H.history["val_classified_accuracy"], label="val_accuracy")
	plt.title("Training accuracy")
	plt.xlabel("Epoch #")
	plt.ylabel("accuracy")
	plt.legend(loc="lower left")
	if plotPath is not None:
		plt.savefig(plotPath)
	else:
		plt.show()

# %%
from utils import *

print("Random State : ", time_string)
plot_training_loss_balancing(history, None)
plot_training_acc_balancing(history, None)
plt.clf()
print_test_result_balancing(model, filepath, x_test, y_test.astype(np.float32), y_test.astype(np.float32), dataset=dataset_name)
# Out:
# Random State :  3039869
# 61/61 [==============================] - 3s 21ms/step - loss: 1.7652 - classified_loss: 0.5992 - contrastive_loss: 1.8948 - classified_accuracy: 0.8323 - contrastive_accuracy: 0.0031
# test acc  :  0.8323013186454773
# test loss :  1.7652349472045898
# f1 score  :  0.811457949085468
# [[175   3   7   0   0   0   0   0   0   1   6   0]
#  [  7 158   7   0   0   0   0   0   0   3  10   0]
#  [  1  14 161   0   0   0   0   2   0   4   8   0]
#  [  0   0   8 219   0   0   2   5   2   1   1   0]
#  [  1   0   2   1  86   0   2   1   3   1   1   0]
#  [  0   1   0   0   0 146   0   0   0  14   3   0]
#  [  0   1   3   6   1   0 173   1   0   1   2   0]
#  [  0   0  14   2   0   1   2  80   7  10   1   0]
#  [  0   2   8   8   0   3   0  33  34   6   7   3]
#  [  2   1   6   1   0   3   0   3   0 146  13   0]
#  [  0   7  12   0   0   2   0   0   0  18 199   0]
#  [  0   2   2   0   1   0   0   2   3   2   1  36]]
